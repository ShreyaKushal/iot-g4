# %%
# !pip install pmdarima

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
import warnings

# %%
from math import sqrt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1>Sensor 1 Data (3-hours interval) as of 13 March 2024</h1>

# %%
df1 = pd.read_csv('../data/sensor1.csv')

# %% [markdown]
# <h2>Data Cleaning</h2>

# %% [markdown]
# We are focusing on <b>Temperature</b>, <b>Humidity</b>, and <b>CO2</b> variables.

# %%
df1.drop(["PM10", "PM2.5", "TVOC"], axis=1, inplace=True)

# %%
df1 = df1.dropna()

# %%
units_dict = {}

for col in df1.columns[1:]:
    values = []
    units = set()
    for val in df1[col]:
        value, unit = val.split()
        values.append(value)
        units.add(unit)
    new_col_name = f"{col} ({units.pop()})"
    df1.rename(columns={col: new_col_name}, inplace=True)
    df1[new_col_name] = pd.to_numeric(values)
    units_dict[col] = units

# %%
df1['Time'] = pd.to_datetime(df1['Time'])

# %%
df1.index = df1['Time']
df1.drop(columns=['Time'], inplace=True)

# %%
df1 = df1.reindex(columns=['Temperature (°C)', 'Humidity (%H)', 'CO2 (ppm)'])

# %% [markdown]
# Exponential smoothing is used to assign exponentially decreasing weights to past observations. This gives more weight to recent observations while still considering older ones.

# %%
# df1 = df1.ewm(alpha=0.2).mean()

# %%
df1.shape
# Out:
# (1457, 3)

# %%
df1.head()
# Out:
#                      Temperature (°C)  Humidity (%H)  CO2 (ppm)
# Time
# 2024-03-13 20:00:00              23.6           78.3        615
# 2024-03-13 17:00:00              23.2           77.6        689
# 2024-03-13 14:00:00              23.1           77.2        657
# 2024-03-13 11:00:00              23.2           78.3        590
# 2024-03-13 08:00:00              23.4           78.0        501

# %% [markdown]
# <h2>Train, Test and Predict using window-based ARIMA model</h2>

# %% [markdown]
# <h3>Temperature (°C)</h3>

# %% [markdown]
# First, let's look at <em>Temperature (°C)</em>.

# %%
df1["Temperature (°C)"].plot(figsize=(12,5))

plt.legend()

# %% [markdown]
# Below is to check for stationarity.

# %% [markdown]
# <b>H0:</b> It is non-stationary <br>
# <b>H1:</b> It is stationary
#
# If `p-value <= 0.05`, it has <b>strong</b> evidence against the null hypothesis (H0). We can reject the null hypothesis and conclude that data has no unit root and is stationary.
#
# Else, it has <b>weak</b> evidence against the null hypothesis. We can accept the null hypothesis and conlude that the time series has a unit root and is non-stationary.

# %%
def ad_test(dataset):
    dftest = adfuller(dataset, autolag="AIC")
    print("1. ADF: ", dftest[0])
    print("2. P-Value: ", dftest[1])
    print("3. Number of Lags:", dftest[2])
    print("4. Number of Observations Used for ADF Regression and Critical Values Calculation: ", dftest[3])
    print("5. Critical Values: ")
    for key, value in dftest[4].items():
        print("\t", key, ": ", value)

# %%
ad_test(df1["Temperature (°C)"])
# Out:
# 1. ADF:  -7.357253766077032
# 2. P-Value:  9.707115092495319e-11
# 3. Number of Lags: 24
# 4. Number of Observations Used for ADF Regression and Critical Values Calculation:  1432
# 5. Critical Values:
# 	 1% :  -3.4349247631306237
# 	 5% :  -2.8635604442944658
# 	 10% :  -2.5678456715029183

# %% [markdown]
# Thus, we can reject the null hypothesis and conclude that time series for <em>Temperature (°C)</em> is <b>stationary</b>.

# %%
window_size = 3
step_size = 1

x = []
y = []

# %%
# RE-DO (IN PROGRESS)

# %% [markdown]
# Next, to predict C02, we need to find out how many previous data is required to be considered. <br>
#
# `auto_arima` function helps to automatically determine the <b>order (p, d, q)</b> of the ARIMA.
#
# <b>p</b> refers to the AR model lags <br>
# <b>d</b> refers to the differencing <br>
# <b>q</b> refers to the Moving Average lags

# %%
stepwise_fit_temp = auto_arima(df1["Temperature Seasonal Difference"].dropna(), trace=True, suppress_warnings=True)
stepwise_fit_temp.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-343.365, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-318.061, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-316.062, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-316.062, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-319.747, Time=0.00 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-338.109, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-326.003, Time=0.02 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-362.968, Time=0.08 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-342.042, Time=0.05 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-352.034, Time=0.08 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-376.825, Time=0.08 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-378.962, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-374.077, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-377.733, Time=0.10 sec
# ...

# %% [markdown]
# The best model is of <b>(2,0,5)</b> order and the data does not exhibit seasonality.

# %% [markdown]
# Autocorrelation and partial corrlation functions plots help to provide insights into the underlying structure of the time series for <em>Temperature (°C)</em>.

# %%
fig_temp = plt.figure(figsize=(12,8))
ax1_temp = fig_temp.add_subplot(211)
fig_temp = sm.graphics.tsa.plot_acf(df1["Temperature Seasonal Difference"].iloc[2:], lags=40, ax=ax1_temp)
ax2_temp = fig_temp.add_subplot(212)
fig_temp = sm.graphics.tsa.plot_pacf(df1["Temperature Seasonal Difference"].iloc[2:], lags=40, ax=ax2_temp)

plt.subplots_adjust(hspace=0.4)

# %%
print(df1.shape)
train1 = df1.iloc[:-1]
test1 = df1.iloc[-1:]
print(train1.shape, test1.shape)
# Out:
# (186, 4)
# (185, 4) (1, 4)

# %%
train1["Temperature (°C)"]
# Out:
# Time
# 2024-03-12    23.300000
# 2024-03-11    23.577778
# 2024-03-10    24.037705
# 2024-03-09    23.889431
# 2024-03-08    23.803332
#                 ...
# 2023-09-14    23.928997
# 2023-09-13    23.883197
# 2023-09-12    23.886558
# 2023-09-11    23.869246
# 2023-09-10    24.115397
# Name: Temperature (°C), Length: 185, dtype: float64

# %% [markdown]
# Since the data does not exhibit seasonality, ARIMA is used.

# %%
model_temp = ARIMA(train1["Temperature (°C)"], order=(2, 0, 5))
model_temp = model_temp.fit()
model_temp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:       Temperature (°C)   No. Observations:                  185
# Model:                 ARIMA(2, 0, 5)   Log Likelihood                 191.211
# Date:                Wed, 13 Mar 2024   AIC                           -364.423
# Time:                        18:25:35   BIC                           -335.439
# Sample:                             0   HQIC                          -352.676
#                                 - 185
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.6989      0.082    290.362      0.000      23.539      23.859
# ar.L1          1.0365      0.148      6.984      0.000       0.746       1.327
# ar.L2         -0.0805      0.114     -0.706      0.480      -0.304       0.143
# ...

# %%
start1 = len(train1)
end1 = len(train1) + len(test1) - 1

# %%
test1
# Out:
#             Temperature (°C)  Humidity (%H)   CO2 (ppm)  \
# Time
# 2023-09-09         24.072318      75.835257  605.817175
#
#             Temperature Seasonal Difference
# Time
# 2023-09-09                        -0.043079

# %%
pred_temp = model_temp.predict(start=start1, end=end1, typ="levels")
pred_temp.index = df1.index[start1:end1+1]
print(pred_temp)
# Out:
# Time
# 2023-09-09    24.081704
# dtype: float64

# %%
y_min_temp = min(test1["Temperature (°C)"].min(), pred_temp.min())
y_max_temp = max(test1["Temperature (°C)"].max(), pred_temp.max())

plt.figure(figsize=(12, 6))
plt.plot(test1.index, test1["Temperature (°C)"], label='Actual Temperature (°C)', color='blue')
plt.plot(test1.index, pred_temp, label='Predicted Temperature (°C)', color='red')

plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual Temperature vs Predicted Temperature (°C)')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %%
rmse_temp = sqrt(mean_squared_error(test1['Temperature (°C)'], pred_temp))
print("RMSE:", round(rmse_temp,2))
# Out:
# RMSE: 0.11

# %% [markdown]
# The RMSE value for <em>Temperature (°C)</em> is <b>0.11</b>. We will then proceed to re-train the model on the entire dataset and make prediction on future value.

# %%
model_temp2 = ARIMA(df1["Temperature (°C)"], order=(2, 0, 5))
model_temp2 = model_temp2.fit()
df1.head()
# Out:
#             Temperature (°C)  Humidity (%H)   CO2 (ppm)  \
# Time
# 2024-03-12         23.300000      77.900000  510.000000
# 2024-03-11         23.577778      77.733333  616.111111
# 2024-03-10         24.037705      78.252459  573.852459
# 2024-03-09         23.889431      78.844444  559.674797
# 2024-03-08         23.803332      79.069205  611.532604
#
#             Temperature Seasonal Difference
# Time
# 2024-03-12                              NaN
# 2024-03-11                         0.277778
# 2024-03-10                         0.459927
# 2024-03-09                        -0.148274
# 2024-03-08                        -0.086099

# %% [markdown]
# We will make a prediction on the next <b>30</b> days.

# %%
index_future_dates = pd.date_range(start=df1.index[0], end=df1.index[0] + pd.Timedelta(days=1))
pred_temp2 = model_temp2.predict(start=len(df1), end=len(df1) + 1, typ="levels").rename("ARIMA Predictions")
pred_temp2.index = index_future_dates
pred_temp2
# Out:
# 2024-03-12    24.116658
# 2024-03-13    23.986450
# Freq: D, Name: ARIMA Predictions, dtype: float64

# %%
plt.figure(figsize=(12, 5))
pred_temp2.plot(legend=True)

# y_min_temp = min(test1["Temperature (°C)"].min(), pred_temp.min())
# y_max_temp = max(test1["Temperature (°C)"].max(), pred_temp.max())

# y_min_rounded_temp = np.floor(y_min_temp)
# y_max_rounded_temp = np.ceil(y_max_temp)

plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
# plt.yticks(np.arange(y_min_rounded_temp, y_max_rounded_temp+1, 1))

plt.show()

# %% [markdown]
# <h3>Humidity (%H)</h3>

# %% [markdown]
# Second, let's look at <em>Humidity (%H)</em>.

# %%
df1["Humidity (%H)"].plot(figsize=(12,5))

plt.legend()

# %%
ad_test(df1["Humidity (%H)"])
# Out:
# 1. ADF:  -0.5525894150050019
# 2. P-Value:  0.8813391222887426
# 3. Number of Lags: 15
# 4. Number of Observations Used for ADF Regression and Critical Values Calculation:  170
# 5. Critical Values:
# 	 1% :  -3.469413468959902
# 	 5% :  -2.8786964197028295
# 	 10% :  -2.5759166089965397

# %% [markdown]
# Time series for <em>Humidity (%H)</em> is <b>non-stationary</b> thus differencing is used.

# %%
df1["Humidity Seasonal Difference"] = df1["Humidity (%H)"] - df1["Humidity (%H)"].shift(1)

# %%
ad_test(df1["Humidity Seasonal Difference"].dropna())
# Out:
# 1. ADF:  -2.9605436137887238
# 2. P-Value:  0.038747054242109724
# 3. Number of Lags: 14
# 4. Number of Observations Used for ADF Regression and Critical Values Calculation:  170
# 5. Critical Values:
# 	 1% :  -3.469413468959902
# 	 5% :  -2.8786964197028295
# 	 10% :  -2.5759166089965397

# %%
df1["Humidity Seasonal Difference"].plot(figsize=(12,5))

plt.legend()

# %%
stepwise_fit_humdity = auto_arima(df1["Humidity Seasonal Difference"].dropna(), trace=True, suppress_warnings=True)
stepwise_fit_humdity.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-169.688, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-125.954, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-129.375, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-139.924, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-127.884, Time=0.00 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-166.777, Time=0.08 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-186.641, Time=0.11 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=-171.957, Time=0.10 sec
# ...

# %% [markdown]
# The best model is of <b>(5,1,3)</b> order and the data does not exhibit seasonality.

# %%
fig_humidity = plt.figure(figsize=(12,8))
ax1_humidity = fig_humidity.add_subplot(211)
fig_humidity = sm.graphics.tsa.plot_acf(df1["Humidity Seasonal Difference"].iloc[2:], lags=40, ax=ax1_humidity)
ax2_humidity = fig_humidity.add_subplot(212)
fig_humidity = sm.graphics.tsa.plot_pacf(df1["Humidity Seasonal Difference"].iloc[2:], lags=40, ax=ax2_humidity)

plt.subplots_adjust(hspace=0.4)

# %%
model_humidity = ARIMA(train1["Humidity (%H)"], order=(5, 1, 3))
model_humidity = model_humidity.fit()
model_humidity.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:          Humidity (%H)   No. Observations:                  156
# Model:                 ARIMA(5, 1, 3)   Log Likelihood                 101.917
# Date:                Wed, 13 Mar 2024   AIC                           -185.834
# Time:                        18:01:07   BIC                           -158.443
# Sample:                             0   HQIC                          -174.708
#                                 - 156
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2405      0.442      0.544      0.586      -0.626       1.107
# ar.L2         -0.6404      0.206     -3.105      0.002      -1.045      -0.236
# ar.L3          0.4172      0.380      1.097      0.272      -0.328       1.162
# ...

# %%
pred_humidity = model_humidity.predict(start=start1, end=end1, typ="levels")
pred_humidity.index = df1.index[start1:end1+1]
print(pred_humidity)
# Out:
# Time
# 2023-10-08    75.294184
# 2023-10-07    75.264931
# 2023-10-06    75.176780
# 2023-10-05    75.226288
# 2023-10-04    75.337726
# 2023-10-03    75.301259
# 2023-10-02    75.249268
# 2023-10-01    75.325026
# 2023-09-30    75.349147
# 2023-09-29    75.261110
# 2023-09-28    75.264670
# 2023-09-27    75.342218
# 2023-09-26    75.305153
# 2023-09-25    75.244003
# 2023-09-24    75.304385
# 2023-09-23    75.340814
# 2023-09-22    75.269105
# 2023-09-21    75.262545
# 2023-09-20    75.334522
# 2023-09-19    75.312574
# 2023-09-18    75.251528
# 2023-09-17    75.296530
# 2023-09-16    75.337762
# 2023-09-15    75.278108
# 2023-09-14    75.261683
# 2023-09-13    75.325752
# 2023-09-12    75.316512
# 2023-09-11    75.258273
# 2023-09-10    75.290035
# 2023-09-09    75.333826
# Name: predicted_mean, dtype: float64

# %%
y_min_humidity = min(test1["Humidity (%H)"].min(), pred_humidity.min())
y_max_humidity = max(test1["Humidity (%H)"].max(), pred_humidity.max())

plt.figure(figsize=(12, 6))
plt.plot(test1.index, test1["Humidity (%H)"], label='Actual Humidity (%H)', color='blue')
plt.plot(test1.index, pred_humidity, label='Predicted Humidity (%H)', color='red')

plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual Humidity vs Predicted Humidity (°C)')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %%
rmse_humidity = sqrt(mean_squared_error(test1['Humidity (%H)'], pred_humidity))
print("RMSE:", round(rmse_humidity,2))
# Out:
# RMSE: 0.44

# %% [markdown]
# The RMSE value for <em>Humidity (%H)</em> is <b>0.44</b>. We will then proceed to re-train the model on the entire dataset and make prediction on future value.

# %%
model_humidity2 = ARIMA(df1["Humidity (%H)"], order=(5, 1, 3))
model_humidity2 = model_humidity2.fit()
df1.head()
# Out:
#             Temperature (°C)  Humidity (%H)   CO2 (ppm)  \
# Time
# 2024-03-12         23.300000      77.900000  510.000000
# 2024-03-11         23.577778      77.733333  616.111111
# 2024-03-10         24.037705      78.252459  573.852459
# 2024-03-09         23.889431      78.844444  559.674797
# 2024-03-08         23.803332      79.069205  611.532604
#
#             Temperature Seasonal Difference  Humidity Seasonal Difference
# Time
# 2024-03-12                              NaN                           NaN
# 2024-03-11                         0.277778                     -0.166667
# 2024-03-10                         0.459927                      0.519126
# 2024-03-09                        -0.148274                      0.591985
# 2024-03-08                        -0.086099                      0.224761

# %%
pred_humidity2 = model_humidity2.predict(start=len(df1), end=len(df1) + 30, typ="levels").rename("ARIMA Predictions")
pred_humidity2.index = index_future_dates
pred_humidity2
# Out:
# 2024-03-12    75.981052
# 2024-03-13    76.040530
# 2024-03-14    76.147593
# 2024-03-15    76.091306
# 2024-03-16    75.919883
# 2024-03-17    75.924371
# 2024-03-18    76.000443
# 2024-03-19    75.923808
# 2024-03-20    75.876322
# 2024-03-21    75.987511
# 2024-03-22    76.010809
# 2024-03-23    75.907321
# 2024-03-24    75.931758
# 2024-03-25    76.023426
# 2024-03-26    75.959902
# 2024-03-27    75.891559
# 2024-03-28    75.978504
# 2024-03-29    76.010193
# 2024-03-30    75.912523
# 2024-03-31    75.920712
# 2024-04-01    76.013871
# 2024-04-02    75.969357
# 2024-04-03    75.895743
# 2024-04-04    75.968490
# 2024-04-05    76.011781
# 2024-04-06    75.923200
# 2024-04-07    75.915740
# 2024-04-08    76.005548
# 2024-04-09    75.977330
# 2024-04-10    75.900443
# 2024-04-11    75.958563
# Freq: D, Name: ARIMA Predictions, dtype: float64

# %%
plt.figure(figsize=(12, 5))
pred_humidity2.plot(legend=True)

plt.xlabel('Date')
plt.ylabel('Humidity (%H)')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <h3>CO2 (ppm)</h3>

# %% [markdown]
# Third, let's look at <em>CO2 (ppm)</em>.

# %%
df1["CO2 (ppm)"].plot(figsize=(12,5))

plt.legend()

# %%
ad_test(df1["CO2 (ppm)"])
# Out:
# 1. ADF:  -3.3596258719517658
# 2. P-Value:  0.012414678686211926
# 3. Number of Lags: 15
# 4. Number of Observations Used for ADF Regression and Critical Values Calculation:  170
# 5. Critical Values:
# 	 1% :  -3.469413468959902
# 	 5% :  -2.8786964197028295
# 	 10% :  -2.5759166089965397

# %% [markdown]
# We can reject the null hypothesis and conclude that time series for <em>CO2 (ppm)</em> is <b>stationary</b>.

# %%
stepwise_fit_co2 = auto_arima(df1["CO2 (ppm)"].dropna(), d=0, trace=True, seasonal=False, suppress_warnings=True, stepwise=True)
stepwise_fit_co2.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1719.017, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2897.203, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1720.581, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1722.933, Time=0.02 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1721.609, Time=0.10 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1720.967, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1724.937, Time=0.02 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1720.809, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1720.207, Time=0.04 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1709.062, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1707.476, Time=0.04 sec
# ...

# %% [markdown]
# The best model is of <b>(1,0,1)</b> order and the data does not exhibit seasonality.

# %%
fig_co2 = plt.figure(figsize=(12,8))
ax1_co2 = fig_co2.add_subplot(211)
fig_co2 = sm.graphics.tsa.plot_acf(df1["CO2 (ppm)"].iloc[2:], lags=40, ax=ax1_co2)
ax2_co2 = fig_temp.add_subplot(212)
fig_co2 = sm.graphics.tsa.plot_pacf(df1["CO2 (ppm)"].iloc[2:], lags=40, ax=ax2_co2)

plt.subplots_adjust(hspace=0.4)

# %%
model_co2 = ARIMA(train1["CO2 (ppm)"], order=(1, 0, 1))
model_co2 = model_co2.fit()
model_co2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:              CO2 (ppm)   No. Observations:                  156
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -715.457
# Date:                Wed, 13 Mar 2024   AIC                           1438.913
# Time:                        18:01:09   BIC                           1451.113
# Sample:                             0   HQIC                          1443.868
#                                 - 156
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        571.2956     20.753     27.528      0.000     530.620     611.971
# ar.L1          0.8418      0.038     21.970      0.000       0.767       0.917
# ma.L1          0.3431      0.080      4.307      0.000       0.187       0.499
# ...

# %%
pred_co2 = model_co2.predict(start=start1, end=end1, typ="levels")
pred_co2.index = df1.index[start1:end1+1]
print(pred_co2)
# Out:
# Time
# 2023-10-08    510.487261
# 2023-10-07    520.108108
# 2023-10-06    528.206784
# 2023-10-05    535.024121
# 2023-10-04    540.762847
# 2023-10-03    545.593616
# 2023-10-02    549.660080
# 2023-10-01    553.083166
# 2023-09-30    555.964665
# 2023-09-29    558.390265
# 2023-09-28    560.432097
# 2023-09-27    562.150879
# 2023-09-26    563.597722
# 2023-09-25    564.815652
# 2023-09-24    565.840886
# 2023-09-23    566.703911
# 2023-09-22    567.430392
# 2023-09-21    568.041933
# 2023-09-20    568.556718
# 2023-09-19    568.990056
# 2023-09-18    569.354833
# 2023-09-17    569.661896
# 2023-09-16    569.920377
# 2023-09-15    570.137963
# 2023-09-14    570.321123
# 2023-09-13    570.475304
# 2023-09-12    570.605091
# 2023-09-11    570.714344
# 2023-09-10    570.806311
# 2023-09-09    570.883728
# Name: predicted_mean, dtype: float64

# %%
y_min_co2 = min(test1["CO2 (ppm)"].min(), pred_co2.min())
y_max_co2 = max(test1["CO2 (ppm)"].max(), pred_co2.max())

plt.figure(figsize=(12, 6))
plt.plot(test1.index, test1["CO2 (ppm)"], label='Actual CO2 (ppm)', color='blue')
plt.plot(test1.index, pred_co2, label='Predicted CO2 (ppm)', color='red')

plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual CO2 vs Predicted CO2 (ppm)')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %%
rmse_co2 = sqrt(mean_squared_error(test1['CO2 (ppm)'], pred_co2))
print("RMSE:", round(rmse_co2,2))
# Out:
# RMSE: 36.86

# %% [markdown]
# The RSME value for <em>CO2 (ppm)</em> is 36.86. We will then proceed to re-train the model on the entire dataset and make prediction on future value.

# %%
model_co2_2 = ARIMA(df1["CO2 (ppm)"], order=(1, 0, 1))
model_co2_2 = model_co2_2.fit()
df1.head()
# Out:
#             Temperature (°C)  Humidity (%H)   CO2 (ppm)  \
# Time
# 2024-03-12         23.300000      77.900000  510.000000
# 2024-03-11         23.577778      77.733333  616.111111
# 2024-03-10         24.037705      78.252459  573.852459
# 2024-03-09         23.889431      78.844444  559.674797
# 2024-03-08         23.803332      79.069205  611.532604
#
#             Temperature Seasonal Difference  Humidity Seasonal Difference
# Time
# 2024-03-12                              NaN                           NaN
# 2024-03-11                         0.277778                     -0.166667
# 2024-03-10                         0.459927                      0.519126
# 2024-03-09                        -0.148274                      0.591985
# 2024-03-08                        -0.086099                      0.224761

# %%
pred_co2 = model_co2_2.predict(start=len(df1), end=len(df1) + 30, typ="levels").rename("ARIMA Predictions")
pred_co2.index = index_future_dates
pred_co2
# Out:
# 2024-03-12    605.971149
# 2024-03-13    600.763918
# 2024-03-14    596.464341
# 2024-03-15    592.914208
# 2024-03-16    589.982887
# 2024-03-17    587.562514
# 2024-03-18    585.564028
# 2024-03-19    583.913891
# 2024-03-20    582.551384
# 2024-03-21    581.426371
# 2024-03-22    580.497455
# 2024-03-23    579.730455
# 2024-03-24    579.097149
# 2024-03-25    578.574232
# 2024-03-26    578.142462
# 2024-03-27    577.785953
# 2024-03-28    577.491586
# 2024-03-29    577.248529
# 2024-03-30    577.047838
# 2024-03-31    576.882129
# 2024-04-01    576.745304
# 2024-04-02    576.632329
# 2024-04-03    576.539046
# 2024-04-04    576.462023
# 2024-04-05    576.398425
# 2024-04-06    576.345913
# 2024-04-07    576.302554
# 2024-04-08    576.266753
# 2024-04-09    576.237193
# 2024-04-10    576.212784
# 2024-04-11    576.192631
# Freq: D, Name: ARIMA Predictions, dtype: float64

# %%
plt.figure(figsize=(12, 5))
pred_co2.plot(legend=True)

plt.xlabel('Date')
plt.ylabel('CO2 (ppm)')
plt.xticks(rotation=45)

plt.show()
