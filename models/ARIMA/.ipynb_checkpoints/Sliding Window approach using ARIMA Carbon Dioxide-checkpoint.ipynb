# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /opt/anaconda3/lib/python3.11/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (3.0.9)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (68.2.2)
# Requirement already satisfied: packaging>=17.1 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import statsmodels.api as sm
import warnings

# %%
from math import sqrt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../../data/sensor1.csv')

# %%
df = df.dropna()

# %%
df
# Out:
#                      Time      CO2 Humidity        PM10       PM2.5  \
# 0     2024-02-12 22:00:00  456 ppm    79 %H  5.60 μg/m³  5.60 μg/m³
# 1     2024-02-12 23:00:00  456 ppm    79 %H  5.25 μg/m³  5.13 μg/m³
# 2     2024-02-13 00:00:00  456 ppm    79 %H     6 μg/m³  5.89 μg/m³
# 3     2024-02-13 01:00:00  450 ppm    79 %H  6.44 μg/m³  6.33 μg/m³
# 4     2024-02-13 02:00:00  447 ppm    79 %H  6.25 μg/m³  5.88 μg/m³
# ...                   ...      ...      ...         ...         ...
# 1162  2024-04-01 10:00:00  599 ppm  74.8 %H  16.8 μg/m³  16.5 μg/m³
# 1163  2024-04-01 11:00:00  695 ppm  74.9 %H  14.5 μg/m³  14.3 μg/m³
# 1164  2024-04-01 12:00:00  779 ppm  74.7 %H  12.8 μg/m³  12.2 μg/m³
# 1165  2024-04-01 13:00:00  796 ppm  74.8 %H  11.2 μg/m³    11 μg/m³
# 1166  2024-04-01 14:00:00  762 ppm  75.2 %H    12 μg/m³    11 μg/m³
#
#      Temperature       TVOC
# 0          24 °C  0.642 ppm
# 1        24.1 °C  0.711 ppm
# 2        24.2 °C  0.744 ppm
# 3        24.2 °C  0.759 ppm
# 4        24.3 °C  0.775 ppm
# ...          ...        ...
# 1162     23.4 °C  0.702 ppm
# 1163     23.4 °C  0.577 ppm
# 1164     23.3 °C  0.535 ppm
# 1165     23.3 °C  0.402 ppm
# 1166     23.2 °C  0.377 ppm
#
# [1167 rows x 7 columns]

# %%
units_dict = {}

for col in df.columns[1:]:
    values = []
    units = set()
    for val in df[col]:
        value, unit = val.split()
        values.append(value)
        units.add(unit)
    new_col_name = f"{col} ({units.pop()})"
    df.rename(columns={col: new_col_name}, inplace=True)
    df[new_col_name] = pd.to_numeric(values)
    units_dict[col] = units

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df.index = df['Time']
df.drop(columns=['Time'], inplace=True)

# %%
df = df.sort_index()

# %%
co2 = df["CO2 (ppm)"]

# %%
co2.plot(y='CO2 (ppm)', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('Time', fontsize=12)
plt.ylabel('CO2 (ppm)', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Create training and testing datasets

# %%
train_size = int(0.8 * len(df))

# %%
train_df = df.iloc[:train_size]
test_df = df.iloc[train_size:]

# %%
train_start_dt = train_df.index[0]
test_start_dt = test_df.index[0]

# %%
train_start_dt, test_start_dt
# Out:
# (Timestamp('2024-02-12 22:00:00'), Timestamp('2024-03-22 21:00:00'))

# %%
df
# Out:
#                      CO2 (ppm)  Humidity (%H)  PM10 (μg/m³)  PM2.5 (μg/m³)  \
# Time
# 2024-02-12 22:00:00        456           79.0          5.60           5.60
# 2024-02-12 23:00:00        456           79.0          5.25           5.13
# 2024-02-13 00:00:00        456           79.0          6.00           5.89
# 2024-02-13 01:00:00        450           79.0          6.44           6.33
# 2024-02-13 02:00:00        447           79.0          6.25           5.88
# ...                        ...            ...           ...            ...
# 2024-04-01 10:00:00        599           74.8         16.80          16.50
# 2024-04-01 11:00:00        695           74.9         14.50          14.30
# 2024-04-01 12:00:00        779           74.7         12.80          12.20
# 2024-04-01 13:00:00        796           74.8         11.20          11.00
# 2024-04-01 14:00:00        762           75.2         12.00          11.00
#
#                      Temperature (°C)  TVOC (ppm)
# Time
# 2024-02-12 22:00:00              24.0       0.642
# 2024-02-12 23:00:00              24.1       0.711
# 2024-02-13 00:00:00              24.2       0.744
# 2024-02-13 01:00:00              24.2       0.759
# 2024-02-13 02:00:00              24.3       0.775
# ...                               ...         ...
# 2024-04-01 10:00:00              23.4       0.702
# 2024-04-01 11:00:00              23.4       0.577
# 2024-04-01 12:00:00              23.3       0.535
# 2024-04-01 13:00:00              23.3       0.402
# 2024-04-01 14:00:00              23.2       0.377
#
# [1167 rows x 6 columns]

# %%
test_co2 = df[df.index >= test_start_dt]["CO2 (ppm)"]
train_co2 = df[(df.index < test_start_dt) & (df.index >= train_start_dt)]["CO2 (ppm)"]

plt.figure(figsize=(15, 8))
plt.plot(test_co2.index, test_co2.values, label='Test')

plt.plot(train_co2.index, train_co2.values, label='Train')

plt.xlabel('Time')
plt.ylabel('CO2 (ppm)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# Data preparation

# %%
train_co2_reshaped = train_co2.values.reshape(-1, 1)
test_co2_reshaped = test_co2.values.reshape(-1, 1)

# %%
print("Training data shape: ", train_co2_reshaped.shape)
print("Test data shape: ", test_co2_reshaped.shape)
# Out:
# Training data shape:  (933, 1)
# Test data shape:  (234, 1)

# %%
scaler = MinMaxScaler()
train_co2_scaled = scaler.fit_transform(train_co2_reshaped)
train_co2_scaled = pd.DataFrame(train_co2_scaled.flatten(), index=train_co2.index, columns=["CO2 (ppm)"])
train_co2_scaled.head(10)
# Out:
#                      CO2 (ppm)
# Time
# 2024-02-12 22:00:00   0.030124
# 2024-02-12 23:00:00   0.030124
# 2024-02-13 00:00:00   0.030124
# 2024-02-13 01:00:00   0.026195
# 2024-02-13 02:00:00   0.024231
# 2024-02-13 03:00:00   0.021611
# 2024-02-13 04:00:00   0.018337
# 2024-02-13 05:00:00   0.015062
# 2024-02-13 06:00:00   0.015062
# 2024-02-13 07:00:00   0.014407

# %%
train_co2_scaled.plot.hist(bins=10)
plt.show()

# %%
test_co2_scaled = scaler.fit_transform(test_co2_reshaped)
test_co2_scaled = pd.DataFrame(test_co2_scaled.flatten(), index=test_co2.index, columns=["CO2 (ppm)"])
test_co2_scaled.head(10)
# Out:
#                      CO2 (ppm)
# Time
# 2024-03-22 21:00:00   0.205240
# 2024-03-22 22:00:00   0.195051
# 2024-03-22 23:00:00   0.183406
# 2024-03-23 00:00:00   0.174672
# 2024-03-23 01:00:00   0.163028
# 2024-03-23 02:00:00   0.147016
# 2024-03-23 03:00:00   0.138282
# 2024-03-23 04:00:00   0.128093
# 2024-03-23 05:00:00   0.109170
# 2024-03-23 06:00:00   0.093159

# %%
test_co2_scaled.plot.hist(bins=10)
plt.show()

# %%
HORIZON_CO2 = 1

# %%
stepwise_fit_co2 = auto_arima(train_co2_scaled, trace=True, suppress_warnings=True)
stepwise_fit_co2.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-4109.316, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-1160.171, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-3515.721, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2314.507, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-305.060, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-4102.533, Time=0.18 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-4105.225, Time=0.18 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-4104.179, Time=0.22 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-4107.026, Time=0.24 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-4013.062, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-4111.786, Time=0.27 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-3588.103, Time=0.14 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=-4111.322, Time=0.42 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-3102.645, Time=0.14 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=-3807.279, Time=0.39 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-4091.253, Time=0.38 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-4080.021, Time=0.10 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 3.102 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  933
# Model:               SARIMAX(1, 0, 3)   Log Likelihood                2061.893
# Date:                Mon, 01 Apr 2024   AIC                          -4111.786
# Time:                        19:59:11   BIC                          -4082.756
# Sample:                             0   HQIC                         -4100.716
#                                 - 933
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0199      0.005      3.865      0.000       0.010       0.030
# ar.L1          0.8737      0.014     60.358      0.000       0.845       0.902
# ma.L1          0.9365      0.016     59.650      0.000       0.906       0.967
# ma.L2          0.4616      0.027     17.218      0.000       0.409       0.514
# ma.L3          0.1239      0.023      5.379      0.000       0.079       0.169
# sigma2         0.0007   1.26e-05     55.780      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             13080.01
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.41   Skew:                             2.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
order_co2 = (1,0,3)

# %%
model_temp =  ARIMA(endog=train_co2_scaled, order=order_co2)
result_temp = model_temp.fit()

print(result_temp.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              CO2 (ppm)   No. Observations:                  933
# Model:                 ARIMA(1, 0, 3)   Log Likelihood                2061.893
# Date:                Mon, 01 Apr 2024   AIC                          -4111.786
# Time:                        19:59:12   BIC                          -4082.756
# Sample:                             0   HQIC                         -4100.716
#                                 - 933
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1576      0.027      5.806      0.000       0.104       0.211
# ar.L1          0.8737      0.014     60.372      0.000       0.845       0.902
# ma.L1          0.9364      0.016     59.650      0.000       0.906       0.967
# ma.L2          0.4615      0.027     17.219      0.000       0.409       0.514
# ma.L3          0.1238      0.023      5.378      0.000       0.079       0.169
# sigma2         0.0007   1.26e-05     55.792      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             13080.35
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.41   Skew:                             2.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Walk-forward validation

# %% [markdown]
# Create a test data point for each HORIZON.<br>
# Shift the data horizontally according to its horizon point.

# %%
test_co2_shifted = test_co2_scaled.copy()

for t in range(1, HORIZON_CO2):
    test_co2_shifted["CO2 (ppm)+" + str(t)] = test_co2_shifted["CO2 (ppm)"].shift(-t, freq='H')
    
test_co2_shifted = test_co2_shifted.dropna(how='any')
test_co2_shifted.head()
# Out:
#                      CO2 (ppm)
# Time
# 2024-03-22 21:00:00   0.205240
# 2024-03-22 22:00:00   0.195051
# 2024-03-22 23:00:00   0.183406
# 2024-03-23 00:00:00   0.174672
# 2024-03-23 01:00:00   0.163028

# %% [markdown]
# Make predictions on the test data using a sliding window approach in a loop the size of the test data length.

# %%
stepwise_fit_co2_test = auto_arima(test_co2_scaled, trace=True, suppress_warnings=True)
stepwise_fit_co2_test.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-825.862, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-673.538, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-781.322, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-798.040, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-675.427, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-828.907, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-829.923, Time=0.03 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-829.179, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-816.202, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-832.753, Time=0.03 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-825.620, Time=0.10 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-830.303, Time=0.12 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-827.757, Time=0.08 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,1,3)(0,0,0)[0] intercept
# Total fit time: 0.878 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  234
# Model:               SARIMAX(1, 1, 3)   Log Likelihood                 422.377
# Date:                Mon, 01 Apr 2024   AIC                           -832.753
# Time:                        19:59:13   BIC                           -812.047
# Sample:                    03-22-2024   HQIC                          -824.404
#                          - 04-01-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   7.446e-06      0.000      0.038      0.969      -0.000       0.000
# ar.L1          0.9275      0.042     22.253      0.000       0.846       1.009
# ma.L1         -0.0246      0.053     -0.463      0.644      -0.129       0.080
# ma.L2         -0.5271      0.039    -13.364      0.000      -0.604      -0.450
# ma.L3         -0.4183      0.053     -7.876      0.000      -0.522      -0.314
# sigma2         0.0015   8.04e-05     19.233      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2616.35
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.28   Skew:                             2.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_co2_shifted
# Out:
#                      CO2 (ppm)
# Time
# 2024-03-22 21:00:00   0.205240
# 2024-03-22 22:00:00   0.195051
# 2024-03-22 23:00:00   0.183406
# 2024-03-23 00:00:00   0.174672
# 2024-03-23 01:00:00   0.163028
# ...                        ...
# 2024-04-01 10:00:00   0.256186
# 2024-04-01 11:00:00   0.395924
# 2024-04-01 12:00:00   0.518195
# 2024-04-01 13:00:00   0.542940
# 2024-04-01 14:00:00   0.493450
#
# [234 rows x 1 columns]

# %%
# %%time
training_window = 168

train_ts_co2 = train_co2_scaled["CO2 (ppm)"]
test_ts_co2 = test_co2_shifted

history_co2 = [x for x in train_ts_co2]
history_co2 = history_co2[(-training_window):]

predictions_co2 = list()

# order = (1,1,1)

for t in range(test_ts_co2.shape[0]):
    model_co2 = ARIMA(endog=history_co2, order=order_co2)
    model_fit_co2 = model_co2.fit()
    yhat = model_fit_co2.forecast(steps = HORIZON_CO2)
    predictions_co2.append(yhat)
    obs = list(test_ts_co2.iloc[t])
    # move the training window
    history_co2.append(obs[0])
    history_co2.pop(0)
    print(test_ts_co2.index[t])
    print(t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# 2024-03-22 21:00:00
# 1 : predicted = [0.10385195] expected = [0.20524017467248912]
# 2024-03-22 22:00:00
# 2 : predicted = [0.2834159] expected = [0.19505094614264928]
# 2024-03-22 23:00:00
# 3 : predicted = [0.14091044] expected = [0.183406113537118]
# 2024-03-23 00:00:00
# 4 : predicted = [0.20706796] expected = [0.1746724890829695]
# 2024-03-23 01:00:00
# 5 : predicted = [0.15149945] expected = [0.16302765647743822]
# 2024-03-23 02:00:00
# 6 : predicted = [0.16579078] expected = [0.1470160116448327]
# 2024-03-23 03:00:00
# 7 : predicted = [0.13449988] expected = [0.1382823871906842]
# 2024-03-23 04:00:00
# 8 : predicted = [0.13855593] expected = [0.12809315866084425]
# 2024-03-23 05:00:00
# 9 : predicted = [0.12141813] expected = [0.10917030567685593]
# 2024-03-23 06:00:00
# 10 : predicted = [0.1016434] expected = [0.0931586608442504]
# 2024-03-23 07:00:00
# 11 : predicted = [0.08867159] expected = [0.0931586608442504]
# 2024-03-23 08:00:00
# 12 : predicted = [0.09816797] expected = [0.0844250363901019]
# 2024-03-23 09:00:00
# 13 : predicted = [0.07951258] expected = [0.07423580786026207]
# 2024-03-23 10:00:00
# 14 : predicted = [0.07388418] expected = [0.055312954876273746]
# 2024-03-23 11:00:00
# 15 : predicted = [0.04758933] expected = [0.05385735080058229]
# 2024-03-23 12:00:00
# 16 : predicted = [0.06220663] expected = [0.06259097525473079]
# 2024-03-23 13:00:00
# 17 : predicted = [0.06920817] expected = [0.07278020378457062]
# 2024-03-23 14:00:00
# 18 : predicted = [0.08091811] expected = [0.07569141193595341]
# 2024-03-23 15:00:00
# 19 : predicted = [0.07772279] expected = [0.0844250363901019]
# 2024-03-23 16:00:00
# 20 : predicted = [0.09294281] expected = [0.0931586608442504]
# 2024-03-23 17:00:00
# 21 : predicted = [0.09791569] expected = [0.11062590975254738]
# 2024-03-23 18:00:00
# 22 : predicted = [0.12221422] expected = [0.11935953420669587]
# 2024-03-23 19:00:00
# 23 : predicted = [0.12106508] expected = [0.11935953420669587]
# 2024-03-23 20:00:00
# 24 : predicted = [0.12009951] expected = [0.11790393013100442]
# 2024-03-23 21:00:00
# 25 : predicted = [0.11793501] expected = [0.12518195050946146]
# 2024-03-23 22:00:00
# 26 : predicted = [0.13120926] expected = [0.12518195050946146]
# 2024-03-23 23:00:00
# 27 : predicted = [0.12337828] expected = [0.11935953420669587]
# 2024-03-24 00:00:00
# 28 : predicted = [0.11799834] expected = [0.11644832605531297]
# 2024-03-24 01:00:00
# 29 : predicted = [0.11681891] expected = [0.09461426491994185]
# 2024-03-24 02:00:00
# 30 : predicted = [0.08298248] expected = [0.0902474526928676]
# 2024-03-24 03:00:00
# 31 : predicted = [0.09664232] expected = [0.07132459970887928]
# 2024-03-24 04:00:00
# 32 : predicted = [0.06024789] expected = [0.06695778748180503]
# 2024-03-24 05:00:00
# 33 : predicted = [0.07495724] expected = [0.05240174672489084]
# 2024-03-24 06:00:00
# 34 : predicted = [0.0451137] expected = [0.0451237263464338]
# 2024-03-24 07:00:00
# 35 : predicted = [0.05140483] expected = [0.039301310043668214]
# 2024-03-24 08:00:00
# 36 : predicted = [0.03995831] expected = [0.03202328966521106]
# 2024-03-24 09:00:00
# 37 : predicted = [0.03508537] expected = [0.027656477438136817]
# 2024-03-24 10:00:00
# 38 : predicted = [0.03154551] expected = [0.024745269286754024]
# 2024-03-24 11:00:00
# 39 : predicted = [0.02956308] expected = [0.026200873362445476]
# 2024-03-24 12:00:00
# 40 : predicted = [0.03352948] expected = [0.03202328966521106]
# 2024-03-24 13:00:00
# 41 : predicted = [0.04082411] expected = [0.05385735080058229]
# 2024-03-24 14:00:00
# 42 : predicted = [0.07135808] expected = [0.06259097525473079]
# 2024-03-24 15:00:00
# 43 : predicted = [0.06695953] expected = [0.06841339155749637]
# 2024-03-24 16:00:00
# 44 : predicted = [0.07671896] expected = [0.0844250363901019]
# 2024-03-24 17:00:00
# 45 : predicted = [0.09606998] expected = [0.10771470160116448]
# 2024-03-24 18:00:00
# 46 : predicted = [0.12124645] expected = [0.1266375545851529]
# 2024-03-24 19:00:00
# 47 : predicted = [0.13488063] expected = [0.12518195050946146]
# 2024-03-24 20:00:00
# 48 : predicted = [0.12215235] expected = [0.1353711790393014]
# 2024-03-24 21:00:00
# 49 : predicted = [0.14461417] expected = [0.14410480349344978]
# 2024-03-24 22:00:00
# 50 : predicted = [0.14604923] expected = [0.141193595342067]
# 2024-03-24 23:00:00
# 51 : predicted = [0.13928551] expected = [0.1353711790393014]
# 2024-03-25 00:00:00
# 52 : predicted = [0.13345066] expected = [0.12227074235807867]
# 2024-03-25 01:00:00
# 53 : predicted = [0.11668871] expected = [0.12227074235807867]
# 2024-03-25 02:00:00
# 54 : predicted = [0.12739601] expected = [0.10189228529839889]
# 2024-03-25 03:00:00
# 55 : predicted = [0.0899601] expected = [0.0989810771470161]
# 2024-03-25 04:00:00
# 56 : predicted = [0.10732248] expected = [0.0931586608442504]
# 2024-03-25 05:00:00
# 57 : predicted = [0.09051837] expected = [0.08151382823871911]
# 2024-03-25 06:00:00
# 58 : predicted = [0.08135737] expected = [0.07132459970887928]
# 2024-03-25 07:00:00
# 59 : predicted = [0.07156891] expected = [0.07132459970887928]
# 2024-03-25 08:00:00
# 60 : predicted = [0.07896852] expected = [0.15866084425036397]
# 2024-03-25 09:00:00
# 61 : predicted = [0.21378352] expected = [0.20669577874818057]
# 2024-03-25 10:00:00
# 62 : predicted = [0.20860765] expected = [0.32314410480349354]
# 2024-03-25 11:00:00
# 63 : predicted = [0.38075866] expected = [0.6739446870451238]
# 2024-03-25 12:00:00
# 64 : predicted = [0.88662353] expected = [0.9286754002911208]
# 2024-03-25 13:00:00
# 65 : predicted = [0.99252703] expected = [0.9694323144104804]
# 2024-03-25 14:00:00
# 66 : predicted = [0.92349586] expected = [0.7933042212518195]
# 2024-03-25 15:00:00
# 67 : predicted = [0.58325973] expected = [0.7379912663755459]
# 2024-03-25 16:00:00
# 68 : predicted = [0.73251007] expected = [0.6622998544395926]
# 2024-03-25 17:00:00
# 69 : predicted = [0.58958613] expected = [0.5691411935953421]
# 2024-03-25 18:00:00
# 70 : predicted = [0.48226159] expected = [0.4643377001455604]
# 2024-03-25 19:00:00
# 71 : predicted = [0.40581286] expected = [0.3886462882096071]
# 2024-03-25 20:00:00
# 72 : predicted = [0.34026993] expected = [0.3435225618631733]
# 2024-03-25 21:00:00
# 73 : predicted = [0.31846128] expected = [0.33333333333333337]
# 2024-03-25 22:00:00
# 74 : predicted = [0.32768243] expected = [0.32605531295487633]
# 2024-03-25 23:00:00
# 75 : predicted = [0.31174365] expected = [0.31732168850072784]
# 2024-03-26 00:00:00
# 76 : predicted = [0.30434333] expected = [0.3129548762736536]
# 2024-03-26 01:00:00
# 77 : predicted = [0.30601994] expected = [0.307132459970888]
# 2024-03-26 02:00:00
# 78 : predicted = [0.29572024] expected = [0.2925764192139738]
# 2024-03-26 03:00:00
# 79 : predicted = [0.27644995] expected = [0.26928675400291124]
# 2024-03-26 04:00:00
# 80 : predicted = [0.25104521] expected = [0.2532751091703057]
# 2024-03-26 05:00:00
# 81 : predicted = [0.24404837] expected = [0.23289665211062593]
# 2024-03-26 06:00:00
# 82 : predicted = [0.21830037] expected = [0.2197962154294032]
# 2024-03-26 07:00:00
# 83 : predicted = [0.21316989] expected = [0.20087336244541487]
# 2024-03-26 08:00:00
# 84 : predicted = [0.18957921] expected = [0.18195050946142655]
# 2024-03-26 09:00:00
# 85 : predicted = [0.17217033] expected = [0.14556040756914124]
# 2024-03-26 10:00:00
# 86 : predicted = [0.12545751] expected = [0.12518195050946146]
# 2024-03-26 11:00:00
# 87 : predicted = [0.12405939] expected = [0.19359534206695783]
# 2024-03-26 12:00:00
# 88 : predicted = [0.25569027] expected = [0.25473071324599716]
# 2024-03-26 13:00:00
# 89 : predicted = [0.27404878] expected = [0.264919941775837]
# 2024-03-26 14:00:00
# 90 : predicted = [0.24894861] expected = [0.23726346433770018]
# 2024-03-26 15:00:00
# 91 : predicted = [0.21850778] expected = [0.2227074235807861]
# 2024-03-26 16:00:00
# 92 : predicted = [0.21891277] expected = [0.2227074235807861]
# 2024-03-26 17:00:00
# 93 : predicted = [0.22486888] expected = [0.2227074235807861]
# 2024-03-26 18:00:00
# 94 : predicted = [0.21976256] expected = [0.22707423580786035]
# 2024-03-26 19:00:00
# 95 : predicted = [0.22968431] expected = [0.22707423580786035]
# 2024-03-26 20:00:00
# 96 : predicted = [0.22445079] expected = [0.22416302765647744]
# 2024-03-26 21:00:00
# 97 : predicted = [0.22005969] expected = [0.24454148471615722]
# 2024-03-26 22:00:00
# 98 : predicted = [0.26043878] expected = [0.264919941775837]
# 2024-03-26 23:00:00
# 99 : predicted = [0.2699591] expected = [0.2678311499272198]
# 2024-03-27 00:00:00
# 100 : predicted = [0.25887118] expected = [0.2678311499272198]
# 2024-03-27 01:00:00
# 101 : predicted = [0.26589898] expected = [0.25473071324599716]
# 2024-03-27 02:00:00
# 102 : predicted = [0.24104151] expected = [0.2314410480349346]
# 2024-03-27 03:00:00
# 103 : predicted = [0.21464424] expected = [0.2168850072780204]
# 2024-03-27 04:00:00
# 104 : predicted = [0.21310532] expected = [0.20232896652110632]
# 2024-03-27 05:00:00
# 105 : predicted = [0.19373008] expected = [0.19068413391557504]
# 2024-03-27 06:00:00
# 106 : predicted = [0.18570481] expected = [0.1717612809315866]
# 2024-03-27 07:00:00
# 107 : predicted = [0.16253405] expected = [0.18195050946142655]
# 2024-03-27 08:00:00
# 108 : predicted = [0.19695347] expected = [0.3013100436681223]
# 2024-03-27 09:00:00
# 109 : predicted = [0.38959159] expected = [0.3377001455604076]
# 2024-03-27 10:00:00
# 110 : predicted = [0.31537396] expected = [0.34788937409024756]
# 2024-03-27 11:00:00
# 111 : predicted = [0.33984906] expected = [0.4337700145560408]
# 2024-03-27 12:00:00
# 112 : predicted = [0.48762396] expected = [0.6288209606986901]
# 2024-03-27 13:00:00
# 113 : predicted = [0.72886281] expected = [0.7103347889374092]
# 2024-03-27 14:00:00
# 114 : predicted = [0.68345899] expected = [0.5618631732168851]
# 2024-03-27 15:00:00
# 115 : predicted = [0.39179357] expected = [0.4687045123726348]
# 2024-03-27 16:00:00
# 116 : predicted = [0.45108323] expected = [0.4250363901018923]
# 2024-03-27 17:00:00
# 117 : predicted = [0.41072634] expected = [0.5356622998544396]
# 2024-03-27 18:00:00
# 118 : predicted = [0.58046028] expected = [0.6273653566229986]
# 2024-03-27 19:00:00
# 119 : predicted = [0.67005681] expected = [0.6652110625909753]
# 2024-03-27 20:00:00
# 120 : predicted = [0.61653818] expected = [0.5633187772925765]
# 2024-03-27 21:00:00
# 121 : predicted = [0.46892686] expected = [0.512372634643377]
# 2024-03-27 22:00:00
# 122 : predicted = [0.49529422] expected = [0.4687045123726348]
# 2024-03-27 23:00:00
# 123 : predicted = [0.4402946] expected = [0.42940320232896667]
# 2024-03-28 00:00:00
# 124 : predicted = [0.37964393] expected = [0.38136826783114997]
# 2024-03-28 01:00:00
# 125 : predicted = [0.36302857] expected = [0.3464337700145561]
# 2024-03-28 02:00:00
# 126 : predicted = [0.31959905] expected = [0.3129548762736536]
# 2024-03-28 03:00:00
# 127 : predicted = [0.28983034] expected = [0.2852983988355168]
# 2024-03-28 04:00:00
# 128 : predicted = [0.27358782] expected = [0.2532751091703057]
# 2024-03-28 05:00:00
# 129 : predicted = [0.23116858] expected = [0.23289665211062593]
# 2024-03-28 06:00:00
# 130 : predicted = [0.22603794] expected = [0.2081513828238719]
# 2024-03-28 07:00:00
# 131 : predicted = [0.19774872] expected = [0.21251819505094616]
# 2024-03-28 08:00:00
# 132 : predicted = [0.22034689] expected = [0.3129548762736536]
# 2024-03-28 09:00:00
# 133 : predicted = [0.39329356] expected = [0.3435225618631733]
# 2024-03-28 10:00:00
# 134 : predicted = [0.3223822] expected = [0.44687045123726343]
# 2024-03-28 11:00:00
# 135 : predicted = [0.49618035] expected = [0.7743813682678313]
# 2024-03-28 12:00:00
# 136 : predicted = [1.00602545] expected = [1.0]
# 2024-03-28 13:00:00
# 137 : predicted = [1.00946618] expected = [0.9621542940320233]
# 2024-03-28 14:00:00
# 138 : predicted = [0.8146713] expected = [0.8515283842794761]
# 2024-03-28 15:00:00
# 139 : predicted = [0.80152684] expected = [0.7816593886462884]
# 2024-03-28 16:00:00
# 140 : predicted = [0.72330626] expected = [0.7467248908296944]
# 2024-03-28 17:00:00
# 141 : predicted = [0.70712943] expected = [0.7045123726346434]
# 2024-03-28 18:00:00
# 142 : predicted = [0.66547367] expected = [0.5909752547307132]
# 2024-03-28 19:00:00
# 143 : predicted = [0.48211035] expected = [0.48908296943231444]
# 2024-03-28 20:00:00
# 144 : predicted = [0.43775219] expected = [0.42940320232896667]
# 2024-03-28 21:00:00
# 145 : predicted = [0.40773792] expected = [0.40756914119359533]
# 2024-03-28 22:00:00
# 146 : predicted = [0.3862083] expected = [0.3857350800582242]
# 2024-03-28 23:00:00
# 147 : predicted = [0.37085945] expected = [0.3580786026200874]
# 2024-03-29 00:00:00
# 148 : predicted = [0.33419931] expected = [0.33187772925764203]
# 2024-03-29 01:00:00
# 149 : predicted = [0.31580206] expected = [0.307132459970888]
# 2024-03-29 02:00:00
# 150 : predicted = [0.29302491] expected = [0.28093158660844253]
# 2024-03-29 03:00:00
# 151 : predicted = [0.2634169] expected = [0.2561863173216885]
# 2024-03-29 04:00:00
# 152 : predicted = [0.24521233] expected = [0.23580786026200873]
# 2024-03-29 05:00:00
# 153 : predicted = [0.22749579] expected = [0.2168850072780204]
# 2024-03-29 06:00:00
# 154 : predicted = [0.20838715] expected = [0.19650655021834063]
# 2024-03-29 07:00:00
# 155 : predicted = [0.18895448] expected = [0.17903930131004375]
# 2024-03-29 08:00:00
# 156 : predicted = [0.17479848] expected = [0.14992721979621548]
# 2024-03-29 09:00:00
# 157 : predicted = [0.1355905] expected = [0.12081513828238721]
# 2024-03-29 10:00:00
# 158 : predicted = [0.11325416] expected = [0.08588064046579336]
# 2024-03-29 11:00:00
# 159 : predicted = [0.07572163] expected = [0.06113537117903933]
# 2024-03-29 12:00:00
# 160 : predicted = [0.06035751] expected = [0.05385735080058229]
# 2024-03-29 13:00:00
# 161 : predicted = [0.06761765] expected = [0.040756914119359555]
# 2024-03-29 14:00:00
# 162 : predicted = [0.03887079] expected = [0.03202328966521106]
# 2024-03-29 15:00:00
# 163 : predicted = [0.04049516] expected = [0.024745269286754024]
# 2024-03-29 16:00:00
# 164 : predicted = [0.03473639] expected = [0.02911208151382827]
# 2024-03-29 17:00:00
# 165 : predicted = [0.04263165] expected = [0.030567685589519722]
# 2024-03-29 18:00:00
# 166 : predicted = [0.04232021] expected = [0.03202328966521106]
# 2024-03-29 19:00:00
# 167 : predicted = [0.04202546] expected = [0.03784570596797676]
# 2024-03-29 20:00:00
# 168 : predicted = [0.05383947] expected = [0.03639010189228531]
# 2024-03-29 21:00:00
# 169 : predicted = [0.04158981] expected = [0.0451237263464338]
# 2024-03-29 22:00:00
# 170 : predicted = [0.06405308] expected = [0.04221251819505101]
# 2024-03-29 23:00:00
# 171 : predicted = [0.0464635] expected = [0.040756914119359555]
# 2024-03-30 00:00:00
# 172 : predicted = [0.04823964] expected = [0.040756914119359555]
# 2024-03-30 01:00:00
# 173 : predicted = [0.05478607] expected = [0.03639010189228531]
# 2024-03-30 02:00:00
# 174 : predicted = [0.03801584] expected = [0.03784570596797676]
# 2024-03-30 03:00:00
# 175 : predicted = [0.05228744] expected = [0.030567685589519722]
# 2024-03-30 04:00:00
# 176 : predicted = [0.03288954] expected = [0.023289665211062682]
# 2024-03-30 05:00:00
# 177 : predicted = [0.02749875] expected = [0.018922852983988436]
# 2024-03-30 06:00:00
# 178 : predicted = [0.0309417] expected = [0.013100436681222738]
# 2024-03-30 07:00:00
# 179 : predicted = [0.01611738] expected = [0.01601164483260553]
# 2024-03-30 08:00:00
# 180 : predicted = [0.03196374] expected = [0.011644832605531286]
# 2024-03-30 09:00:00
# 181 : predicted = [0.01624595] expected = [0.0]
# 2024-03-30 10:00:00
# 182 : predicted = [-0.00065568] expected = [0.0014556040756914523]
# 2024-03-30 11:00:00
# 183 : predicted = [0.02156073] expected = [0.004366812227074246]
# 2024-03-30 12:00:00
# 184 : predicted = [0.01301173] expected = [0.008733624454148492]
# 2024-03-30 13:00:00
# 185 : predicted = [0.0200967] expected = [0.013100436681222738]
# 2024-03-30 14:00:00
# 186 : predicted = [0.0280521] expected = [0.023289665211062682]
# 2024-03-30 15:00:00
# 187 : predicted = [0.03770575] expected = [0.030567685589519722]
# 2024-03-30 16:00:00
# 188 : predicted = [0.04304993] expected = [0.03784570596797676]
# 2024-03-30 17:00:00
# 189 : predicted = [0.05037899] expected = [0.0451237263464338]
# 2024-03-30 18:00:00
# 190 : predicted = [0.05789363] expected = [0.046579330422125254]
# 2024-03-30 19:00:00
# 191 : predicted = [0.05294252] expected = [0.0509461426491995]
# 2024-03-30 20:00:00
# 192 : predicted = [0.06328714] expected = [0.0451237263464338]
# 2024-03-30 21:00:00
# 193 : predicted = [0.0463363] expected = [0.0509461426491995]
# 2024-03-30 22:00:00
# 194 : predicted = [0.06645214] expected = [0.05240174672489084]
# 2024-03-30 23:00:00
# 195 : predicted = [0.06028108] expected = [0.055312954876273746]
# 2024-03-31 00:00:00
# 196 : predicted = [0.06235126] expected = [0.06404657933042213]
# 2024-03-31 01:00:00
# 197 : predicted = [0.08183905] expected = [0.05967976710334788]
# 2024-03-31 02:00:00
# 198 : predicted = [0.05659641] expected = [0.0509461426491995]
# 2024-03-31 03:00:00
# 199 : predicted = [0.05378862] expected = [0.05385735080058229]
# 2024-03-31 04:00:00
# 200 : predicted = [0.07079573] expected = [0.05240174672489084]
# 2024-03-31 05:00:00
# 201 : predicted = [0.05271585] expected = [0.046579330422125254]
# 2024-03-31 06:00:00
# 202 : predicted = [0.05073871] expected = [0.03784570596797676]
# 2024-03-31 07:00:00
# 203 : predicted = [0.04235213] expected = [0.030567685589519722]
# 2024-03-31 08:00:00
# 204 : predicted = [0.03323201] expected = [0.03493449781659397]
# 2024-03-31 09:00:00
# 205 : predicted = [0.05153179] expected = [0.024745269286754024]
# 2024-03-31 10:00:00
# 206 : predicted = [0.01987494] expected = [0.018922852983988436]
# 2024-03-31 11:00:00
# 207 : predicted = [0.02669233] expected = [0.011644832605531286]
# 2024-03-31 12:00:00
# 208 : predicted = [0.01894769] expected = [0.008733624454148492]
# 2024-03-31 13:00:00
# 209 : predicted = [0.01344844] expected = [0.01601164483260553]
# 2024-03-31 14:00:00
# 210 : predicted = [0.03576402] expected = [0.017467248908296984]
# 2024-03-31 15:00:00
# 211 : predicted = [0.02199632] expected = [0.013100436681222738]
# 2024-03-31 16:00:00
# 212 : predicted = [0.01734583] expected = [0.020378457059679778]
# 2024-03-31 17:00:00
# 213 : predicted = [0.04109173] expected = [0.027656477438136817]
# 2024-03-31 18:00:00
# 214 : predicted = [0.03650289] expected = [0.03784570596797676]
# 2024-03-31 19:00:00
# 215 : predicted = [0.05229514] expected = [0.04366812227074235]
# 2024-03-31 20:00:00
# 216 : predicted = [0.05497025] expected = [0.04221251819505101]
# 2024-03-31 21:00:00
# 217 : predicted = [0.04437] expected = [0.0509461426491995]
# 2024-03-31 22:00:00
# 218 : predicted = [0.07005284] expected = [0.05676855895196509]
# 2024-03-31 23:00:00
# 219 : predicted = [0.064433] expected = [0.05822416302765654]
# 2024-04-01 00:00:00
# 220 : predicted = [0.06288985] expected = [0.055312954876273746]
# 2024-04-01 01:00:00
# 221 : predicted = [0.06292406] expected = [0.055312954876273746]
# 2024-04-01 02:00:00
# 222 : predicted = [0.06130782] expected = [0.05967976710334788]
# 2024-04-01 03:00:00
# 223 : predicted = [0.07142261] expected = [0.055312954876273746]
# 2024-04-01 04:00:00
# 224 : predicted = [0.05561215] expected = [0.0451237263464338]
# 2024-04-01 05:00:00
# 225 : predicted = [0.04465349] expected = [0.046579330422125254]
# 2024-04-01 06:00:00
# 226 : predicted = [0.0625247] expected = [0.04366812227074235]
# 2024-04-01 07:00:00
# 227 : predicted = [0.04247104] expected = [0.04949053857350805]
# 2024-04-01 08:00:00
# 228 : predicted = [0.06377503] expected = [0.14410480349344978]
# 2024-04-01 09:00:00
# 229 : predicted = [0.24099406] expected = [0.16739446870451247]
# 2024-04-01 10:00:00
# 230 : predicted = [0.13558424] expected = [0.2561863173216885]
# 2024-04-01 11:00:00
# 231 : predicted = [0.34073422] expected = [0.39592430858806416]
# 2024-04-01 12:00:00
# 232 : predicted = [0.48501367] expected = [0.5181950509461428]
# 2024-04-01 13:00:00
# 233 : predicted = [0.54825937] expected = [0.5429403202328966]
# 2024-04-01 14:00:00
# 234 : predicted = [0.53385685] expected = [0.4934497816593888]
# CPU times: user 48.5 s, sys: 613 ms, total: 49.1 s
# Wall time: 12.3 s

# %% [markdown]
# Compare the prediction against the actual CO2.

# %%
eval_df_co2 = pd.DataFrame(predictions_co2, columns=['t+'+str(t) for t in range(1, HORIZON_CO2+1)])
eval_df_co2['Time'] = test_co2_scaled.index[0:len(test_co2_scaled.index)-HORIZON_CO2+1]
eval_df_co2 = pd.melt(eval_df_co2, id_vars='Time', value_name='Prediction', var_name='H')
eval_df_co2['Actual'] = np.array(np.transpose(test_ts_co2)).ravel()
eval_df_co2[['Prediction', 'Actual']] = scaler.inverse_transform(eval_df_co2[['Prediction', 'Actual']])
eval_df_co2.head()
# Out:
#                  Time    H  Prediction  Actual
# 0 2024-03-22 21:00:00  t+1  494.346286   564.0
# 1 2024-03-22 22:00:00  t+1  617.706724   557.0
# 2 2024-03-22 23:00:00  t+1  519.805474   549.0
# 3 2024-03-23 00:00:00  t+1  565.255686   543.0
# 4 2024-03-23 01:00:00  t+1  527.080121   535.0

# %% [markdown]
# Check the model accuracy by testing its mean absolute percentage error (MAPE) over all the predictions.

# %%
if (HORIZON_CO2 > 1):
    eval_df_co2['APE'] = (eval_df_co2['Prediction'] - eval_df_co2['Actual']).abs()
    print(eval_df_co2.groupby('H')['APE'].mean())

# %%
# Mean absolute percentage error
def mape(predictions, actuals):
    predictions = np.array(predictions)
    actuals = np.array(actuals)
    return (np.absolute(predictions - actuals) / actuals).mean()

# %%
print('Multi-step forecast MAPE: ', mape(eval_df_co2['Prediction'], eval_df_co2['Actual'])*100, '%')
# Out:
# Multi-step forecast MAPE:  2.3501387896850896 %

# %%
rmse_co2 = sqrt(mean_squared_error(eval_df_co2['Prediction'], eval_df_co2['Actual']))
rmse_co2
# Out:
# 29.733329873290288

# %%
r2_co2 = r2_score(eval_df_co2['Actual'], eval_df_co2['Prediction'])
r2_co2
# Out:
# 0.9590506199481083

# %%
if HORIZON_CO2 == 1:
    eval_df_co2.plot(x='Time', y=['Actual', 'Prediction'], style=['r', 'b'], figsize=(15, 8))
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('CO2 (ppm)', fontsize=12)
    plt.legend(['Actual', 'Prediction'], loc='best')
    plt.show()
else:
    plot_df_co2 = eval_df_co2[(eval_df_co2.H == 't+1')][['Time', 'Actual']]
    for t in range(1, HORIZON_CO2 + 1):
        plot_df_co2['t+' + str(t)] = eval_df_co2[(eval_df_co2.H == 't+' + str(t))]['Prediction'].values

    fig = plt.figure(figsize=(15, 8))
    ax = fig.add_subplot(111)
    ax.plot(plot_df_co2['Time'], plot_df_co2['Actual'], color='red', linewidth=4.0, label='Actual')
    for t in range(1, HORIZON_CO2 + 1):
        x = plot_df_co2['Time'][(t - 1):]
        y = plot_df_co2['t+' + str(t)][0:len(x)]
        ax.plot(x, y, color='blue', linewidth=4 * math.pow(.9, t), alpha=math.pow(0.8, t),
                label='Prediction t+' + str(t))

    ax.legend(loc='best')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('CO2', fontsize=12)
    plt.show()

# %%
next_hour = pd.date_range(start=df.index[-1], periods=2, freq='H')[-1]

# %%
pred_co2 = model_fit_co2.predict(start=len(df), end=len(df), typ="levels")[0]
pred_co2_nonscaled = round(scaler.inverse_transform(np.array(pred_co2).reshape(-1, 1))[0][0], 1)
print(f"{next_hour} {pred_co2_nonscaled}")
# Out:
# 2024-04-01 15:00:00 634.5

# %%
with open('arima_co2.pickle', 'wb') as f:
    pickle.dump(model_fit_co2, f)

# %%
with open('arima_scaler.pickle', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# pred_co2 = model_fit_co2.forecast(steps=2)
# pred_co2

# %%
# round(scaler.inverse_transform(np.array(pred_co2[1]).reshape(-1, 1))[0][0], 1)
