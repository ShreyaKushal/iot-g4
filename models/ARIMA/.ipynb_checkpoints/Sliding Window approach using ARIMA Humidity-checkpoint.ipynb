# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /opt/anaconda3/lib/python3.11/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (3.0.9)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (68.2.2)
# Requirement already satisfied: packaging>=17.1 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import statsmodels.api as sm
import warnings

# %%
from math import sqrt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../../data/sensor1.csv')

# %%
df = df.dropna()

# %%
units_dict = {}

for col in df.columns[1:]:
    values = []
    units = set()
    for val in df[col]:
        value, unit = val.split()
        values.append(value)
        units.add(unit)
    new_col_name = f"{col} ({units.pop()})"
    df.rename(columns={col: new_col_name}, inplace=True)
    df[new_col_name] = pd.to_numeric(values)
    units_dict[col] = units

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df.index = df['Time']
df.drop(columns=['Time'], inplace=True)

# %%
df = df.sort_index()

# %%
humidity = df["Humidity (%H)"]

# %%
humidity.plot(y='Humidity (%H)', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Humidity (%H)', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
z_scores = np.abs((humidity.values - humidity.values.mean()) / humidity.values.std())
threshold = 3
humidity = pd.DataFrame(humidity[z_scores < threshold])

# %% [markdown]
# Create training and testing datasets

# %%
train_size = int(0.8 * len(df))

# %%
train_df = df.iloc[:train_size]
test_df = df.iloc[train_size:]

# %%
train_start_dt = train_df.index[0]
test_start_dt = test_df.index[0]

# %%
train_start_dt, test_start_dt
# Out:
# (Timestamp('2024-02-12 22:00:00'), Timestamp('2024-03-22 21:00:00'))

# %%
df
# Out:
#                      CO2 (ppm)  Humidity (%H)  PM10 (μg/m³)  PM2.5 (μg/m³)  \
# Time
# 2024-02-12 22:00:00        456           79.0          5.60           5.60
# 2024-02-12 23:00:00        456           79.0          5.25           5.13
# 2024-02-13 00:00:00        456           79.0          6.00           5.89
# 2024-02-13 01:00:00        450           79.0          6.44           6.33
# 2024-02-13 02:00:00        447           79.0          6.25           5.88
# ...                        ...            ...           ...            ...
# 2024-04-01 10:00:00        599           74.8         16.80          16.50
# 2024-04-01 11:00:00        695           74.9         14.50          14.30
# 2024-04-01 12:00:00        779           74.7         12.80          12.20
# 2024-04-01 13:00:00        796           74.8         11.20          11.00
# 2024-04-01 14:00:00        762           75.2         12.00          11.00
#
#                      Temperature (°C)  TVOC (ppm)
# Time
# 2024-02-12 22:00:00              24.0       0.642
# 2024-02-12 23:00:00              24.1       0.711
# 2024-02-13 00:00:00              24.2       0.744
# 2024-02-13 01:00:00              24.2       0.759
# 2024-02-13 02:00:00              24.3       0.775
# ...                               ...         ...
# 2024-04-01 10:00:00              23.4       0.702
# 2024-04-01 11:00:00              23.4       0.577
# 2024-04-01 12:00:00              23.3       0.535
# 2024-04-01 13:00:00              23.3       0.402
# 2024-04-01 14:00:00              23.2       0.377
#
# [1167 rows x 6 columns]

# %%
test_humidity = df[df.index >= test_start_dt]["Humidity (%H)"]
train_humidity = df[(df.index < test_start_dt) & (df.index >= train_start_dt)]["Humidity (%H)"]

plt.figure(figsize=(15, 8))
plt.plot(test_humidity.index, test_humidity.values, label='Test')

plt.plot(train_humidity.index, train_humidity.values, label='Train')

plt.xlabel('Time')
plt.ylabel('Humidity (%H)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# Data preparation

# %%
train_humidity_reshaped = train_humidity.values.reshape(-1, 1)
test_humidity_reshaped = test_humidity.values.reshape(-1, 1)

# %%
print("Training data shape: ", train_humidity_reshaped.shape)
print("Test data shape: ", test_humidity_reshaped.shape)
# Out:
# Training data shape:  (933, 1)
# Test data shape:  (234, 1)

# %%
scaler = MinMaxScaler()
train_humidity_scaled = scaler.fit_transform(train_humidity_reshaped)
train_humidity_scaled = pd.DataFrame(train_humidity_scaled.flatten(), index=train_humidity.index, columns=["Humidity (%H)"])
train_humidity_scaled.head(10)
# Out:
#                      Humidity (%H)
# Time
# 2024-02-12 22:00:00       0.729412
# 2024-02-12 23:00:00       0.729412
# 2024-02-13 00:00:00       0.729412
# 2024-02-13 01:00:00       0.729412
# 2024-02-13 02:00:00       0.729412
# 2024-02-13 03:00:00       0.729412
# 2024-02-13 04:00:00       0.729412
# 2024-02-13 05:00:00       0.729412
# 2024-02-13 06:00:00       0.729412
# 2024-02-13 07:00:00       0.729412

# %%
train_humidity_scaled.plot.hist(bins=10)
plt.show()

# %%
test_humidity_scaled = scaler.fit_transform(test_humidity_reshaped)
test_humidity_scaled = pd.DataFrame(test_humidity_scaled.flatten(), index=test_humidity.index, columns=["Humidity (%H)"])
test_humidity_scaled.head(10)
# Out:
#                      Humidity (%H)
# Time
# 2024-03-22 21:00:00       0.793651
# 2024-03-22 22:00:00       0.761905
# 2024-03-22 23:00:00       0.682540
# 2024-03-23 00:00:00       0.682540
# 2024-03-23 01:00:00       0.650794
# 2024-03-23 02:00:00       0.603175
# 2024-03-23 03:00:00       0.603175
# 2024-03-23 04:00:00       0.603175
# 2024-03-23 05:00:00       0.603175
# 2024-03-23 06:00:00       0.603175

# %%
test_humidity_scaled.plot.hist(bins=10)
plt.show()

# %%
HORIZON_HUMIDITY = 1

# %%
stepwise_fit_humidity = auto_arima(train_humidity_scaled, trace=True, suppress_warnings=True)
stepwise_fit_humidity.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-2634.944, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-2575.869, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-2574.054, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-2574.148, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-2577.866, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-2634.822, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-2633.183, Time=0.21 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-2632.573, Time=0.20 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-2630.335, Time=0.32 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-2628.276, Time=0.16 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-2630.770, Time=0.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-2635.910, Time=0.23 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-2599.123, Time=0.03 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-2634.633, Time=0.31 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-2598.427, Time=0.04 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-2604.119, Time=0.04 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-2632.985, Time=0.30 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-2638.370, Time=0.12 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-2635.028, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=-2601.119, Time=0.01 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=-2636.796, Time=0.12 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-2636.923, Time=0.21 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-2600.423, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-2637.958, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=-2606.114, Time=0.02 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=-2634.862, Time=0.17 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 3.441 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  933
# Model:               SARIMAX(3, 1, 1)   Log Likelihood                1324.185
# Date:                Tue, 02 Apr 2024   AIC                          -2638.370
# Time:                        18:45:27   BIC                          -2614.184
# Sample:                             0   HQIC                         -2629.146
#                                 - 933
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8897      0.028     32.005      0.000       0.835       0.944
# ar.L2         -0.1531      0.035     -4.427      0.000      -0.221      -0.085
# ar.L3          0.0811      0.033      2.463      0.014       0.017       0.146
# ma.L1         -0.9609      0.016    -58.779      0.000      -0.993      -0.929
# sigma2         0.0034   5.72e-05     59.622      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7501.11
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.23   Skew:                            -2.01
# Prob(H) (two-sided):                  0.06   Kurtosis:                        16.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
order_humidity = (1,1,3)

# %%
model_humidity =  ARIMA(endog=train_humidity_scaled, order=order_humidity)
result_humidity = model_humidity.fit()

print(result_humidity.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          Humidity (%H)   No. Observations:                  933
# Model:                 ARIMA(1, 1, 3)   Log Likelihood                1324.441
# Date:                Tue, 02 Apr 2024   AIC                          -2638.882
# Time:                        18:45:28   BIC                          -2614.696
# Sample:                             0   HQIC                         -2629.658
#                                 - 933
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8192      0.041     19.779      0.000       0.738       0.900
# ma.L1         -0.8881      0.044    -20.065      0.000      -0.975      -0.801
# ma.L2         -0.1638      0.034     -4.796      0.000      -0.231      -0.097
# ma.L3          0.0911      0.040      2.297      0.022       0.013       0.169
# sigma2         0.0034   5.72e-05     59.628      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7508.25
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.23   Skew:                            -2.00
# Prob(H) (two-sided):                  0.07   Kurtosis:                        16.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Walk-forward validation

# %% [markdown]
# Create a test data point for each HORIZON.<br>
# Shift the data horizontally according to its horizon point.

# %%
test_humidity_shifted = test_humidity_scaled.copy()

for t in range(1, HORIZON_HUMIDITY):
    test_humidity_shifted["Humidity (%H)+" + str(t)] = test_humidity_shifted["Humidity (%H)"].shift(-t, freq='H')
    
test_humidity_shifted = test_humidity_shifted.dropna(how='any')
test_humidity_shifted.head()
# Out:
#                      Humidity (%H)
# Time
# 2024-03-22 21:00:00       0.793651
# 2024-03-22 22:00:00       0.761905
# 2024-03-22 23:00:00       0.682540
# 2024-03-23 00:00:00       0.682540
# 2024-03-23 01:00:00       0.650794

# %% [markdown]
# Make predictions on the test data using a sliding window approach in a loop the size of the test data length.

# %%
stepwise_fit_humidity_test = auto_arima(test_humidity_scaled, trace=True, suppress_warnings=True)
stepwise_fit_humidity_test.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-419.879, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-410.553, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-408.725, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-408.818, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-412.485, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-420.011, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-415.717, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-417.646, Time=0.08 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-415.231, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-419.802, Time=0.08 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-417.252, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-422.098, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-417.586, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-410.743, Time=0.01 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-417.074, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-421.843, Time=0.05 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 1.051 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  234
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                 215.049
# Date:                Tue, 02 Apr 2024   AIC                           -422.098
# Time:                        18:45:29   BIC                           -408.293
# Sample:                    03-22-2024   HQIC                          -416.531
#                          - 04-01-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8085      0.061     13.205      0.000       0.688       0.928
# ma.L1         -0.8894      0.078    -11.434      0.000      -1.042      -0.737
# ma.L2         -0.0944      0.066     -1.425      0.154      -0.224       0.035
# sigma2         0.0092      0.000     26.871      0.000       0.009       0.010
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              4269.77
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.08   Skew:                            -3.12
# Prob(H) (two-sided):                  0.74   Kurtosis:                        23.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_humidity_shifted
# Out:
#                      Humidity (%H)
# Time
# 2024-03-22 21:00:00       0.793651
# 2024-03-22 22:00:00       0.761905
# 2024-03-22 23:00:00       0.682540
# 2024-03-23 00:00:00       0.682540
# 2024-03-23 01:00:00       0.650794
# ...                            ...
# 2024-04-01 10:00:00       0.333333
# 2024-04-01 11:00:00       0.349206
# 2024-04-01 12:00:00       0.317460
# 2024-04-01 13:00:00       0.333333
# 2024-04-01 14:00:00       0.396825
#
# [234 rows x 1 columns]

# %%
# %%time
training_window = 168

train_ts_humidity = train_humidity_scaled["Humidity (%H)"]
test_ts_humidity = test_humidity_shifted

history_humidity = [x for x in train_ts_humidity]
history_humidity = history_humidity[(-training_window):]

predictions_humidity = list()

# order = (0,1,0)

for t in range(test_ts_humidity.shape[0]):
    model_humidity = ARIMA(endog=history_humidity, order=order_humidity)
    model_fit_humidity = model_humidity.fit()
    yhat = model_fit_humidity.forecast(steps = HORIZON_HUMIDITY)
    predictions_humidity.append(yhat)
    obs = list(test_ts_humidity.iloc[t])
    # move the training window
    history_humidity.append(obs[0])
    history_humidity.pop(0)
    print(test_ts_humidity.index[t])
    print(t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# 2024-03-22 21:00:00
# 1 : predicted = [0.6162298] expected = [0.7936507936507944]
# 2024-03-22 22:00:00
# 2 : predicted = [0.74994485] expected = [0.7619047619047628]
# 2024-03-22 23:00:00
# 3 : predicted = [0.71182739] expected = [0.6825396825396837]
# 2024-03-23 00:00:00
# 4 : predicted = [0.67016072] expected = [0.6825396825396837]
# 2024-03-23 01:00:00
# 5 : predicted = [0.67330433] expected = [0.6507936507936503]
# 2024-03-23 02:00:00
# 6 : predicted = [0.64248632] expected = [0.6031746031746028]
# 2024-03-23 03:00:00
# 7 : predicted = [0.6075799] expected = [0.6031746031746028]
# 2024-03-23 04:00:00
# 8 : predicted = [0.60526823] expected = [0.6031746031746028]
# 2024-03-23 05:00:00
# 9 : predicted = [0.60030857] expected = [0.6031746031746028]
# 2024-03-23 06:00:00
# 10 : predicted = [0.60045126] expected = [0.6031746031746028]
# 2024-03-23 07:00:00
# 11 : predicted = [0.60120146] expected = [0.6031746031746028]
# 2024-03-23 08:00:00
# 12 : predicted = [0.60214125] expected = [0.412698412698413]
# 2024-03-23 09:00:00
# 13 : predicted = [0.4536183] expected = [0.6984126984126977]
# 2024-03-23 10:00:00
# 14 : predicted = [0.69668887] expected = [0.7936507936507944]
# 2024-03-23 11:00:00
# 15 : predicted = [0.70664175] expected = [0.8253968253968278]
# 2024-03-23 12:00:00
# 16 : predicted = [0.7608936] expected = [0.8095238095238102]
# 2024-03-23 13:00:00
# 17 : predicted = [0.78075873] expected = [0.8095238095238102]
# 2024-03-23 14:00:00
# 18 : predicted = [0.77550836] expected = [0.7301587301587311]
# 2024-03-23 15:00:00
# 19 : predicted = [0.74541466] expected = [0.6507936507936503]
# 2024-03-23 16:00:00
# 20 : predicted = [0.66195589] expected = [0.6984126984126977]
# 2024-03-23 17:00:00
# 21 : predicted = [0.69849555] expected = [0.7142857142857153]
# 2024-03-23 18:00:00
# 22 : predicted = [0.7026984] expected = [0.7619047619047628]
# 2024-03-23 19:00:00
# 23 : predicted = [0.74301054] expected = [0.8888888888888893]
# 2024-03-23 20:00:00
# 24 : predicted = [0.84097828] expected = [0.8888888888888893]
# 2024-03-23 21:00:00
# 25 : predicted = [0.84039791] expected = [0.8095238095238102]
# 2024-03-23 22:00:00
# 26 : predicted = [0.79141902] expected = [0.7619047619047628]
# 2024-03-23 23:00:00
# 27 : predicted = [0.7617077] expected = [0.7619047619047628]
# 2024-03-24 00:00:00
# 28 : predicted = [0.7607455] expected = [0.7142857142857153]
# 2024-03-24 01:00:00
# 29 : predicted = [0.72011772] expected = [0.6825396825396837]
# 2024-03-24 02:00:00
# 30 : predicted = [0.69771352] expected = [0.6825396825396837]
# 2024-03-24 03:00:00
# 31 : predicted = [0.69465712] expected = [0.6825396825396837]
# 2024-03-24 04:00:00
# 32 : predicted = [0.69117594] expected = [0.6825396825396837]
# 2024-03-24 05:00:00
# 33 : predicted = [0.68992133] expected = [0.6825396825396837]
# 2024-03-24 06:00:00
# 34 : predicted = [0.68882865] expected = [0.6825396825396837]
# 2024-03-24 07:00:00
# 35 : predicted = [0.68808815] expected = [0.6825396825396837]
# 2024-03-24 08:00:00
# 36 : predicted = [0.68746078] expected = [0.6825396825396837]
# 2024-03-24 09:00:00
# 37 : predicted = [0.68693439] expected = [0.6825396825396837]
# 2024-03-24 10:00:00
# 38 : predicted = [0.68643569] expected = [0.6825396825396837]
# 2024-03-24 11:00:00
# 39 : predicted = [0.68597974] expected = [0.6825396825396837]
# 2024-03-24 12:00:00
# 40 : predicted = [0.68538334] expected = [0.6507936507936503]
# 2024-03-24 13:00:00
# 41 : predicted = [0.66034714] expected = [0.6031746031746028]
# 2024-03-24 14:00:00
# 42 : predicted = [0.62480029] expected = [0.6031746031746028]
# 2024-03-24 15:00:00
# 43 : predicted = [0.62415752] expected = [0.6031746031746028]
# 2024-03-24 16:00:00
# 44 : predicted = [0.61862821] expected = [0.6031746031746028]
# 2024-03-24 17:00:00
# 45 : predicted = [0.61734423] expected = [0.6031746031746028]
# 2024-03-24 18:00:00
# 46 : predicted = [0.61595003] expected = [0.6031746031746028]
# 2024-03-24 19:00:00
# 47 : predicted = [0.6151457] expected = [0.6031746031746028]
# 2024-03-24 20:00:00
# 48 : predicted = [0.61440062] expected = [0.6031746031746028]
# 2024-03-24 21:00:00
# 49 : predicted = [0.61350919] expected = [0.6031746031746028]
# 2024-03-24 22:00:00
# 50 : predicted = [0.61307467] expected = [0.6666666666666679]
# 2024-03-24 23:00:00
# 51 : predicted = [0.66208551] expected = [0.6825396825396837]
# 2024-03-25 00:00:00
# 52 : predicted = [0.6702988] expected = [0.6825396825396837]
# 2024-03-25 01:00:00
# 53 : predicted = [0.67506058] expected = [0.6825396825396837]
# 2024-03-25 02:00:00
# 54 : predicted = [0.67642385] expected = [0.6825396825396837]
# 2024-03-25 03:00:00
# 55 : predicted = [0.67717835] expected = [0.6825396825396837]
# 2024-03-25 04:00:00
# 56 : predicted = [0.67745783] expected = [0.6825396825396837]
# 2024-03-25 05:00:00
# 57 : predicted = [0.67749717] expected = [0.6825396825396837]
# 2024-03-25 06:00:00
# 58 : predicted = [0.67767023] expected = [0.6825396825396837]
# 2024-03-25 07:00:00
# 59 : predicted = [0.67803658] expected = [0.6825396825396837]
# 2024-03-25 08:00:00
# 60 : predicted = [0.67843352] expected = [0.0]
# 2024-03-25 09:00:00
# 61 : predicted = [0.13664477] expected = [0.0952380952380949]
# 2024-03-25 10:00:00
# 62 : predicted = [0.2559508] expected = [0.25396825396825307]
# 2024-03-25 11:00:00
# 63 : predicted = [0.33043378] expected = [0.0952380952380949]
# 2024-03-25 12:00:00
# 64 : predicted = [0.11450001] expected = [0.11111111111111249]
# 2024-03-25 13:00:00
# 65 : predicted = [0.13761678] expected = [0.06349206349206327]
# 2024-03-25 14:00:00
# 66 : predicted = [0.0681884] expected = [0.25396825396825307]
# 2024-03-25 15:00:00
# 67 : predicted = [0.2835383] expected = [0.3174603174603181]
# 2024-03-25 16:00:00
# 68 : predicted = [0.31479368] expected = [0.3015873015873005]
# 2024-03-25 17:00:00
# 69 : predicted = [0.31421516] expected = [0.26984126984127066]
# 2024-03-25 18:00:00
# 70 : predicted = [0.28961312] expected = [0.3333333333333339]
# 2024-03-25 19:00:00
# 71 : predicted = [0.35560465] expected = [0.5555555555555571]
# 2024-03-25 20:00:00
# 72 : predicted = [0.53805297] expected = [0.5714285714285712]
# 2024-03-25 21:00:00
# 73 : predicted = [0.53942419] expected = [0.5238095238095237]
# 2024-03-25 22:00:00
# 74 : predicted = [0.52224003] expected = [0.4761904761904763]
# 2024-03-25 23:00:00
# 75 : predicted = [0.48816494] expected = [0.44444444444444464]
# 2024-03-26 00:00:00
# 76 : predicted = [0.46416705] expected = [0.44444444444444464]
# 2024-03-26 01:00:00
# 77 : predicted = [0.4626132] expected = [0.44444444444444464]
# 2024-03-26 02:00:00
# 78 : predicted = [0.45884428] expected = [0.4761904761904763]
# 2024-03-26 03:00:00
# 79 : predicted = [0.48547395] expected = [0.5238095238095237]
# 2024-03-26 04:00:00
# 80 : predicted = [0.52221869] expected = [0.5238095238095237]
# 2024-03-26 05:00:00
# 81 : predicted = [0.52120949] expected = [0.5238095238095237]
# 2024-03-26 06:00:00
# 82 : predicted = [0.52601258] expected = [0.5238095238095237]
# 2024-03-26 07:00:00
# 83 : predicted = [0.5248066] expected = [0.5714285714285712]
# 2024-03-26 08:00:00
# 84 : predicted = [0.56847326] expected = [0.4920634920634921]
# 2024-03-26 09:00:00
# 85 : predicted = [0.49344878] expected = [0.6666666666666679]
# 2024-03-26 10:00:00
# 86 : predicted = [0.6610606] expected = [0.7142857142857153]
# 2024-03-26 11:00:00
# 87 : predicted = [0.67309837] expected = [0.7777777777777768]
# 2024-03-26 12:00:00
# 88 : predicted = [0.74855427] expected = [0.6825396825396837]
# 2024-03-26 13:00:00
# 89 : predicted = [0.6562729] expected = [0.7301587301587311]
# 2024-03-26 14:00:00
# 90 : predicted = [0.71836912] expected = [0.7619047619047628]
# 2024-03-26 15:00:00
# 91 : predicted = [0.73007637] expected = [0.7142857142857153]
# 2024-03-26 16:00:00
# 92 : predicted = [0.69284277] expected = [0.6507936507936503]
# 2024-03-26 17:00:00
# 93 : predicted = [0.64456202] expected = [0.6666666666666679]
# 2024-03-26 18:00:00
# 94 : predicted = [0.6611344] expected = [0.6507936507936503]
# 2024-03-26 19:00:00
# 95 : predicted = [0.6393887] expected = [0.8095238095238102]
# 2024-03-26 20:00:00
# 96 : predicted = [0.78080102] expected = [0.7936507936507944]
# 2024-03-26 21:00:00
# 97 : predicted = [0.7500622] expected = [0.7142857142857153]
# 2024-03-26 22:00:00
# 98 : predicted = [0.69853132] expected = [0.6825396825396837]
# 2024-03-26 23:00:00
# 99 : predicted = [0.67544261] expected = [0.6825396825396837]
# 2024-03-27 00:00:00
# 100 : predicted = [0.67290249] expected = [0.6825396825396837]
# 2024-03-27 01:00:00
# 101 : predicted = [0.66985226] expected = [0.6984126984126977]
# 2024-03-27 02:00:00
# 102 : predicted = [0.68344875] expected = [0.7619047619047628]
# 2024-03-27 03:00:00
# 103 : predicted = [0.73694765] expected = [0.7619047619047628]
# 2024-03-27 04:00:00
# 104 : predicted = [0.73232125] expected = [0.7619047619047628]
# 2024-03-27 05:00:00
# 105 : predicted = [0.73964267] expected = [0.7619047619047628]
# 2024-03-27 06:00:00
# 106 : predicted = [0.73944848] expected = [0.7619047619047628]
# 2024-03-27 07:00:00
# 107 : predicted = [0.74072632] expected = [0.7777777777777768]
# 2024-03-27 08:00:00
# 108 : predicted = [0.75665223] expected = [0.7301587301587311]
# 2024-03-27 09:00:00
# 109 : predicted = [0.71082095] expected = [0.8095238095238102]
# 2024-03-27 10:00:00
# 110 : predicted = [0.79028769] expected = [0.8888888888888893]
# 2024-03-27 11:00:00
# 111 : predicted = [0.84871668] expected = [0.9047619047619069]
# 2024-03-27 12:00:00
# 112 : predicted = [0.86588716] expected = [0.7777777777777768]
# 2024-03-27 13:00:00
# 113 : predicted = [0.75381163] expected = [0.7619047619047628]
# 2024-03-27 14:00:00
# 114 : predicted = [0.75930059] expected = [0.7142857142857153]
# 2024-03-27 15:00:00
# 115 : predicted = [0.70193781] expected = [0.6984126984126977]
# 2024-03-27 16:00:00
# 116 : predicted = [0.69447305] expected = [0.5873015873015888]
# 2024-03-27 17:00:00
# 117 : predicted = [0.58772268] expected = [0.6031746031746028]
# 2024-03-27 18:00:00
# 118 : predicted = [0.61654458] expected = [0.6190476190476186]
# 2024-03-27 19:00:00
# 119 : predicted = [0.61548785] expected = [0.7460317460317469]
# 2024-03-27 20:00:00
# 120 : predicted = [0.73104628] expected = [0.8412698412698418]
# 2024-03-27 21:00:00
# 121 : predicted = [0.8011477] expected = [0.7777777777777768]
# 2024-03-27 22:00:00
# 122 : predicted = [0.74591967] expected = [0.7619047619047628]
# 2024-03-27 23:00:00
# 123 : predicted = [0.74960577] expected = [0.7619047619047628]
# 2024-03-28 00:00:00
# 124 : predicted = [0.74505518] expected = [0.7619047619047628]
# 2024-03-28 01:00:00
# 125 : predicted = [0.74543111] expected = [0.7619047619047628]
# 2024-03-28 02:00:00
# 126 : predicted = [0.7448353] expected = [0.7619047619047628]
# 2024-03-28 03:00:00
# 127 : predicted = [0.74524301] expected = [0.7619047619047628]
# 2024-03-28 04:00:00
# 128 : predicted = [0.74539565] expected = [0.8095238095238102]
# 2024-03-28 05:00:00
# 129 : predicted = [0.78932827] expected = [0.8412698412698418]
# 2024-03-28 06:00:00
# 130 : predicted = [0.81255913] expected = [0.8412698412698418]
# 2024-03-28 07:00:00
# 131 : predicted = [0.81453502] expected = [0.8412698412698418]
# 2024-03-28 08:00:00
# 132 : predicted = [0.82232601] expected = [0.6031746031746028]
# 2024-03-28 09:00:00
# 133 : predicted = [0.59547911] expected = [0.8095238095238102]
# 2024-03-28 10:00:00
# 134 : predicted = [0.81772784] expected = [0.7460317460317469]
# 2024-03-28 11:00:00
# 135 : predicted = [0.72103779] expected = [0.6031746031746028]
# 2024-03-28 12:00:00
# 136 : predicted = [0.6355534] expected = [0.5079365079365097]
# 2024-03-28 13:00:00
# 137 : predicted = [0.53232449] expected = [0.4285714285714306]
# 2024-03-28 14:00:00
# 138 : predicted = [0.46073718] expected = [0.4920634920634921]
# 2024-03-28 15:00:00
# 139 : predicted = [0.51432012] expected = [0.5396825396825395]
# 2024-03-28 16:00:00
# 140 : predicted = [0.54447741] expected = [0.6349206349206362]
# 2024-03-28 17:00:00
# 141 : predicted = [0.62727039] expected = [0.6507936507936503]
# 2024-03-28 18:00:00
# 142 : predicted = [0.63846042] expected = [0.7619047619047628]
# 2024-03-28 19:00:00
# 143 : predicted = [0.74201388] expected = [0.8888888888888893]
# 2024-03-28 20:00:00
# 144 : predicted = [0.84868798] expected = [0.8730158730158735]
# 2024-03-28 21:00:00
# 145 : predicted = [0.83616619] expected = [0.8095238095238102]
# 2024-03-28 22:00:00
# 146 : predicted = [0.78957568] expected = [0.7619047619047628]
# 2024-03-28 23:00:00
# 147 : predicted = [0.75091794] expected = [0.7619047619047628]
# 2024-03-29 00:00:00
# 148 : predicted = [0.75061534] expected = [0.7619047619047628]
# 2024-03-29 01:00:00
# 149 : predicted = [0.74758903] expected = [0.7619047619047628]
# 2024-03-29 02:00:00
# 150 : predicted = [0.7476367] expected = [0.7619047619047628]
# 2024-03-29 03:00:00
# 151 : predicted = [0.74774605] expected = [0.7619047619047628]
# 2024-03-29 04:00:00
# 152 : predicted = [0.74772472] expected = [0.7619047619047628]
# 2024-03-29 05:00:00
# 153 : predicted = [0.74794815] expected = [0.8253968253968278]
# 2024-03-29 06:00:00
# 154 : predicted = [0.80453803] expected = [0.8412698412698418]
# 2024-03-29 07:00:00
# 155 : predicted = [0.81424533] expected = [0.8412698412698418]
# 2024-03-29 08:00:00
# 156 : predicted = [0.81953908] expected = [0.412698412698413]
# 2024-03-29 09:00:00
# 157 : predicted = [0.4407755] expected = [0.6666666666666679]
# 2024-03-29 10:00:00
# 158 : predicted = [0.67915883] expected = [0.8095238095238102]
# 2024-03-29 11:00:00
# 159 : predicted = [0.75996211] expected = [0.8888888888888893]
# 2024-03-29 12:00:00
# 160 : predicted = [0.84412315] expected = [0.9365079365079367]
# 2024-03-29 13:00:00
# 161 : predicted = [0.89290037] expected = [0.9047619047619069]
# 2024-03-29 14:00:00
# 162 : predicted = [0.87202902] expected = [0.8571428571428577]
# 2024-03-29 15:00:00
# 163 : predicted = [0.83748973] expected = [0.7301587301587311]
# 2024-03-29 16:00:00
# 164 : predicted = [0.72883267] expected = [0.6507936507936503]
# 2024-03-29 17:00:00
# 165 : predicted = [0.66491483] expected = [0.6031746031746028]
# 2024-03-29 18:00:00
# 166 : predicted = [0.61861043] expected = [0.6031746031746028]
# 2024-03-29 19:00:00
# 167 : predicted = [0.6161111] expected = [0.7301587301587311]
# 2024-03-29 20:00:00
# 168 : predicted = [0.72021189] expected = [0.7619047619047628]
# 2024-03-29 21:00:00
# 169 : predicted = [0.73964319] expected = [0.7619047619047628]
# 2024-03-29 22:00:00
# 170 : predicted = [0.74613681] expected = [0.7619047619047628]
# 2024-03-29 23:00:00
# 171 : predicted = [0.74792416] expected = [0.7619047619047628]
# 2024-03-30 00:00:00
# 172 : predicted = [0.74933734] expected = [0.7619047619047628]
# 2024-03-30 01:00:00
# 173 : predicted = [0.75067117] expected = [0.7619047619047628]
# 2024-03-30 02:00:00
# 174 : predicted = [0.75151426] expected = [0.7619047619047628]
# 2024-03-30 03:00:00
# 175 : predicted = [0.75193832] expected = [0.7619047619047628]
# 2024-03-30 04:00:00
# 176 : predicted = [0.75220129] expected = [0.7619047619047628]
# 2024-03-30 05:00:00
# 177 : predicted = [0.75252597] expected = [0.7619047619047628]
# 2024-03-30 06:00:00
# 178 : predicted = [0.75443669] expected = [0.7936507936507944]
# 2024-03-30 07:00:00
# 179 : predicted = [0.78123709] expected = [0.8412698412698418]
# 2024-03-30 08:00:00
# 180 : predicted = [0.82393439] expected = [0.4920634920634921]
# 2024-03-30 09:00:00
# 181 : predicted = [0.51394497] expected = [0.6666666666666679]
# 2024-03-30 10:00:00
# 182 : predicted = [0.69091992] expected = [0.8730158730158735]
# 2024-03-30 11:00:00
# 183 : predicted = [0.82757311] expected = [0.8888888888888893]
# 2024-03-30 12:00:00
# 184 : predicted = [0.8433787] expected = [0.8730158730158735]
# 2024-03-30 13:00:00
# 185 : predicted = [0.84658942] expected = [0.8095238095238102]
# 2024-03-30 14:00:00
# 186 : predicted = [0.79707081] expected = [0.7777777777777768]
# 2024-03-30 15:00:00
# 187 : predicted = [0.7764334] expected = [0.6507936507936503]
# 2024-03-30 16:00:00
# 188 : predicted = [0.66273596] expected = [0.7777777777777768]
# 2024-03-30 17:00:00
# 189 : predicted = [0.78136184] expected = [0.8730158730158735]
# 2024-03-30 18:00:00
# 190 : predicted = [0.83712133] expected = [0.9682539682539684]
# 2024-03-30 19:00:00
# 191 : predicted = [0.92832052] expected = [0.984126984126986]
# 2024-03-30 20:00:00
# 192 : predicted = [0.94184932] expected = [1.0]
# 2024-03-30 21:00:00
# 193 : predicted = [0.96441838] expected = [0.9206349206349209]
# 2024-03-30 22:00:00
# 194 : predicted = [0.89601548] expected = [0.8412698412698418]
# 2024-03-30 23:00:00
# 195 : predicted = [0.83725018] expected = [0.8412698412698418]
# 2024-03-31 00:00:00
# 196 : predicted = [0.83827526] expected = [0.8412698412698418]
# 2024-03-31 01:00:00
# 197 : predicted = [0.83294846] expected = [0.8412698412698418]
# 2024-03-31 02:00:00
# 198 : predicted = [0.83340036] expected = [0.8412698412698418]
# 2024-03-31 03:00:00
# 199 : predicted = [0.83326362] expected = [0.8412698412698418]
# 2024-03-31 04:00:00
# 200 : predicted = [0.83365628] expected = [0.8412698412698418]
# 2024-03-31 05:00:00
# 201 : predicted = [0.83399076] expected = [0.8412698412698418]
# 2024-03-31 06:00:00
# 202 : predicted = [0.83435939] expected = [0.8412698412698418]
# 2024-03-31 07:00:00
# 203 : predicted = [0.83472447] expected = [0.8412698412698418]
# 2024-03-31 08:00:00
# 204 : predicted = [0.83508819] expected = [0.8412698412698418]
# 2024-03-31 09:00:00
# 205 : predicted = [0.83543738] expected = [0.8412698412698418]
# 2024-03-31 10:00:00
# 206 : predicted = [0.83579294] expected = [0.8412698412698418]
# 2024-03-31 11:00:00
# 207 : predicted = [0.83612677] expected = [0.8412698412698418]
# 2024-03-31 12:00:00
# 208 : predicted = [0.83651874] expected = [0.8412698412698418]
# 2024-03-31 13:00:00
# 209 : predicted = [0.83692231] expected = [0.7619047619047628]
# 2024-03-31 14:00:00
# 210 : predicted = [0.76933207] expected = [0.7619047619047628]
# 2024-03-31 15:00:00
# 211 : predicted = [0.77651654] expected = [0.7619047619047628]
# 2024-03-31 16:00:00
# 212 : predicted = [0.77030443] expected = [0.7619047619047628]
# 2024-03-31 17:00:00
# 213 : predicted = [0.77065521] expected = [0.7619047619047628]
# 2024-03-31 18:00:00
# 214 : predicted = [0.76985179] expected = [0.7619047619047628]
# 2024-03-31 19:00:00
# 215 : predicted = [0.76960053] expected = [0.7619047619047628]
# 2024-03-31 20:00:00
# 216 : predicted = [0.7692709] expected = [0.7619047619047628]
# 2024-03-31 21:00:00
# 217 : predicted = [0.76904747] expected = [0.8095238095238102]
# 2024-03-31 22:00:00
# 218 : predicted = [0.80896506] expected = [0.8412698412698418]
# 2024-03-31 23:00:00
# 219 : predicted = [0.83179203] expected = [0.8412698412698418]
# 2024-04-01 00:00:00
# 220 : predicted = [0.83257893] expected = [0.9206349206349209]
# 2024-04-01 01:00:00
# 221 : predicted = [0.9022136] expected = [0.9206349206349209]
# 2024-04-01 02:00:00
# 222 : predicted = [0.89538934] expected = [0.9206349206349209]
# 2024-04-01 03:00:00
# 223 : predicted = [0.90025088] expected = [0.9206349206349209]
# 2024-04-01 04:00:00
# 224 : predicted = [0.90015321] expected = [0.9206349206349209]
# 2024-04-01 05:00:00
# 225 : predicted = [0.9004647] expected = [0.9206349206349209]
# 2024-04-01 06:00:00
# 226 : predicted = [0.90248322] expected = [0.9206349206349209]
# 2024-04-01 07:00:00
# 227 : predicted = [0.90492235] expected = [0.9206349206349209]
# 2024-04-01 08:00:00
# 228 : predicted = [0.91547529] expected = [0.25396825396825307]
# 2024-04-01 09:00:00
# 229 : predicted = [0.33648848] expected = [0.14285714285714235]
# 2024-04-01 10:00:00
# 230 : predicted = [0.26395053] expected = [0.3333333333333339]
# 2024-04-01 11:00:00
# 231 : predicted = [0.50518212] expected = [0.34920634920634974]
# 2024-04-01 12:00:00
# 232 : predicted = [0.41971433] expected = [0.3174603174603181]
# 2024-04-01 13:00:00
# 233 : predicted = [0.37357571] expected = [0.3333333333333339]
# 2024-04-01 14:00:00
# 234 : predicted = [0.39354925] expected = [0.3968253968253972]
# CPU times: user 41.6 s, sys: 1.11 s, total: 42.7 s
# Wall time: 10.7 s

# %% [markdown]
# Compare the prediction against the actual Humidity.

# %%
eval_df_humidity = pd.DataFrame(predictions_humidity, columns=['t+'+str(t) for t in range(1, HORIZON_HUMIDITY+1)])
eval_df_humidity['Time'] = test_humidity_scaled.index[0:len(test_humidity_scaled.index)-HORIZON_HUMIDITY+1]
eval_df_humidity = pd.melt(eval_df_humidity, id_vars='Time', value_name='Prediction', var_name='H')
eval_df_humidity['Actual'] = np.array(np.transpose(test_ts_humidity)).ravel()
eval_df_humidity[['Prediction', 'Actual']] = scaler.inverse_transform(eval_df_humidity[['Prediction', 'Actual']])
eval_df_humidity.head()
# Out:
#                  Time    H  Prediction  Actual
# 0 2024-03-22 21:00:00  t+1   76.582248    77.7
# 1 2024-03-22 22:00:00  t+1   77.424653    77.5
# 2 2024-03-22 23:00:00  t+1   77.184513    77.0
# 3 2024-03-23 00:00:00  t+1   76.922013    77.0
# 4 2024-03-23 01:00:00  t+1   76.941817    76.8

# %% [markdown]
# Check the model accuracy by testing its mean absolute percentage error (MAPE) over all the predictions.

# %%
if (HORIZON_HUMIDITY > 1):
    eval_df_humidity['APE'] = (eval_df_humidity['Prediction'] - eval_df_humidity['Actual']).abs()
    print(eval_df_humidity.groupby('H')['APE'].mean())

# %%
# Mean absolute percentage error
def mape(predictions, actuals):
    predictions = np.array(predictions)
    actuals = np.array(actuals)
    return (np.absolute(predictions - actuals) / actuals).mean()

# %%
print('Multi-step forecast MAPE: ', mape(eval_df_humidity['Prediction'], eval_df_humidity['Actual'])*100, '%')
# Out:
# Multi-step forecast MAPE:  0.4442036349353173 %

# %%
rmse_humidity = sqrt(mean_squared_error(eval_df_humidity['Prediction'], eval_df_humidity['Actual']))
rmse_humidity
# Out:
# 0.6234545984403825

# %%
r2_humidity = r2_score(eval_df_humidity['Actual'], eval_df_humidity['Prediction'])
r2_humidity
# Out:
# 0.689053122145329

# %%
if HORIZON_HUMIDITY == 1:
    eval_df_humidity.plot(x='Time', y=['Actual', 'Prediction'], style=['r', 'b'], figsize=(15, 8))
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Humidity (%H)', fontsize=12)
    plt.legend(['Actual', 'Prediction'], loc='best')
    plt.show()
else:
    plot_df_humidity = eval_df_humidity[(eval_df_humidity.H == 't+1')][['Time', 'Actual']]
    for t in range(1, HORIZON_HUMIDITY + 1):
        plot_df_humidity['t+' + str(t)] = eval_df_humidity[(eval_df_humidity.H == 't+' + str(t))]['Prediction'].values

    fig = plt.figure(figsize=(15, 8))
    ax = fig.add_subplot(111)
    ax.plot(plot_df_humidity['Time'], plot_df_humidity['Actual'], color='red', linewidth=4.0, label='Actual')
    for t in range(1, HORIZON_HUMIDITY + 1):
        x = plot_df_humidity['Time'][(t - 1):]
        y = plot_df_humidity['t+' + str(t)][0:len(x)]
        ax.plot(x, y, color='blue', linewidth=4 * math.pow(.9, t), alpha=math.pow(0.8, t),
                label='Prediction t+' + str(t))

    ax.legend(loc='best')
    plt.xlabel('Time', fontsize=12)
    plt.ylabel('Humidity (%H)', fontsize=12)
    plt.show()

# %%
next_hour = pd.date_range(start=df.index[-1], periods=2, freq='H')[-1]

# %%
pred_humidity = model_fit_humidity.predict(start=len(df), end=len(df), typ="levels")[0]
pred_humidity_nonscaled = round(scaler.inverse_transform(np.array(pred_humidity).reshape(-1, 1))[0][0], 1)
print(f"{next_hour} {pred_humidity_nonscaled}")
# Out:
# 2024-04-01 15:00:00 75.9

# %%
with open('arima_humidity.pickle', 'wb') as f:
    pickle.dump(model_fit_humidity, f)

# %%
with open('arima_scaler_humidity.pickle', 'wb') as f:
    pickle.dump(scaler, f)
